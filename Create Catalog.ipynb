# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import obspy as obs
from obspy.clients.fdsn.client import Client
from obspy.geodetics.base import gps2dist_azimuth
from obspy.geodetics import kilometers2degrees
from obspy.taup import TauPyModel
from obspy.core.utcdatetime import UTCDateTime
import pandas as pd
import os
from scipy import signal
# %matplotlib inline

# %%
############# PARAMETERS #############
mseed_dir = '/Users/rshimony/Desktop/WillametteValley/salem_eq/mseed/'
fig_dir = '/Users/rshimony/Desktop/WillametteValley/salem_eq/figs/'
meta_dir = '/Users/rshimony/Desktop/WillametteValley/salem_eq/metadata/'

## geographic region:
minlat = 43.4
maxlat = 46.7
minlon = -124.2
maxlon = -121.5

## OR central longitude/latitude and radius:
central_lon = -123.05
central_lat = 44.8
search_radius_min = 0 ## in degrees
search_radius_max = 2.5 ## in degrees

## time constraints for event search:
eventTime = UTCDateTime("2022-10-07T12:52:35.448127Z")
stime = eventTime - 60  # 1 minute before the event
etime = eventTime + 15*60  # 15 minutes after the event
# stime = UTCDateTime("2000-01-01T000000.000")
# etime = UTCDateTime("2021-9-20T235959.000")

## min depth in km:
min_depth = 1

## stations of interest:
netcode = '??'
# all_stations = 'BUCK'
channels = '???' # high gain accelerometers, could do high gain broadbands ('HH*',)
channel_split = channels.split(',')
## NOTE: BACME only has HN (W1 loc code); NCBC has

## CLIENTS
## Set up the client to be IRIS, for downloading:
client = Client('IRIS')
# taup:
model = TauPyModel(model="iasp91")

# %%
############# CATALOG DOWNLOADS ##############

## Find stations metadata for position:
sta_inventory = client.get_stations(network=netcode, channel=channels, starttime=stime, endtime=etime, minlatitude = minlat , maxlatitude = maxlat , 
                                      minlongitude = minlon , maxlongitude = maxlon,level="channel")

## Find earthquakes 
#eq_catalog = client.get_events(starttime=stime, endtime=etime,
#                        minlatitude=minlat, maxlatitude=maxlat, 
#                        minlongitude=minlon, maxlongitude=maxlon,
#                        minmagnitude=3)

eq_catalog = client.get_events(starttime=stime, endtime=etime,
                        latitude=central_lat, longitude=central_lon, 
                        minradius=search_radius_min, maxradius=search_radius_max,
                        minmagnitude=3,mindepth=min_depth)

# %%
# print(sta_inventory[3][2].channels[12].code)
# print(sta_inventory[3][2].channels[12].sample_rate)
# print(len(sta_inventory))

sta_inventory[8][5]
# Out:
# Station CARM (McKenzie Bridge, OR, USA)
# 	Station Code: CARM
# 	Channel Count: 17/23 (Selected/Total)
# 	2017-05-04T00:00:00.000000Z -
# 	Access: open
# 	Latitude: 44.30, Longitude: -122.04, Elevation: 991.0 m
# 	Available Channels:
# 		CARM..HNZ, CARM..HNN, CARM..HNE, CARM.D0.GAN, CARM.D0.GEL,
# 		CARM.D0.GLA, CARM.D0.GLO, CARM.D0.GNS, CARM.D0.GPL, CARM.D0.GST,
# 		CARM.D0.LCE, CARM.D0.LCQ, CARM.D0.VCO, CARM.D0.VDT, CARM.D0.VEC,
# 		CARM.D0.VEI, CARM.D0.VPB

# %%
st = Client.get_waveforms(network="UO", station="CARM", location='*',channel='???',
                          starttime=stime, endtime=etime,attach_response=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-22-e017ff78a640> in <module>
# ----> 1 st = Client.get_waveforms(network="UO", station="CARM", location='*',channel='???', starttime=stime, endtime=etime,attach_response=True)
#
# TypeError: get_waveforms() missing 1 required positional argument: 'self'

# %%
# print(sta_inventory[1].code)
# print(channel_split[1][1:-1])
# st.code

# sta_inventory[0][0].elevation

evid_str=str(eq_catalog[35].resource_id)
evid_split = evid_str.split('/')[-1]
ev_id = evid_split.split('=')[-1]
print(evid_str)
print(ev_id)
# Out:
# smi:service.iris.edu/fdsnws/event/1/query?eventid=5157611
# 5157611

# %%
######## GET CATALOG AND METADATA ###########
## Extract the positions of the infrasound stations:
nt_stas = []
st_lons = []
st_lats = []
st_stas = []
st_start_year = []
st_elev = []
st_chan = []
ch_samprt = []
for network in sta_inventory:
    for station in network:
        for channel in station:
            if channel.sample_rate > 21:
                nt_stas.append(network.code)
                st_stas.append(station.code)
                st_lons.append(station.longitude)
                st_lats.append(station.latitude)
                st_start_year.append(station.start_date.year)
                st_elev.append(station.elevation)
                st_chan.append(channel.code)
                ch_samprt.append(channel.sample_rate)
                print(f'{channel.code[0:-1]}N , {channel.code[0:-1]}2')
stdict = {'network':nt_stas, 'name':st_stas, 'longitude':st_lons,
          'latitude':st_lats, 'elevation':st_elev, 'channel':st_chan, 'samprt':ch_samprt }
stdf = pd.DataFrame(stdict)
stdf_nodup=stdf.drop_duplicates()
stdf_nodup.to_csv(meta_dir + 'station_inventory.csv',index=False)
        
# Extract event information:
ev_lons = []
ev_lats = []
ev_depth = []
ev_origint = []
ev_mag = []
ev_id = []
for event in eq_catalog:
    ev_lons.append(event.origins[0].longitude)
    ev_lats.append(event.origins[0].latitude)
    ev_depth.append(event.origins[0].depth)
    ev_origint.append(event.origins[0].time)
    ev_mag.append(event.magnitudes[0].mag)
    evid_str=str(event.resource_id)
    evid_split = evid_str.split('/')[-1]
    evid = evid_split.split('=')[-1]
    ev_id.append(evid)
    
## WRite out event metadata to file to use later:
evdict = {'catalog #':ev_id, 'longitude':ev_lons, 'latitude':ev_lats,'magnitude':ev_mag,
          'depth':ev_depth,'time':ev_origint}
evdf = pd.DataFrame(evdict)
evdf.to_csv(meta_dir + 'event_catalog.csv',index=False)
# Out:
# BHN , BH2
# BHN , BH2
# BHN , BH2
# BDN , BD2
# HDN , HD2
# HDN , HD2
# HDN , HD2
# HDN , HD2
# HDN , HD2
# BHN , BH2
# BHN , BH2
# BHN , BH2
# BHN , BH2
# BHN , BH2
# BHN , BH2
# BDN , BD2
# BDN , BD2
# BDN , BD2
# BHN , BH2
# BHN , BH2
# BHN , BH2
# HHN , HH2
# HHN , HH2
# HHN , HH2
# BHN , BH2
# BHN , BH2
# BHN , BH2
# BHN , BH2
# BHN , BH2
# BHN , BH2
# BDN , BD2
# BHN , BH2
# BHN , BH2
# BHN , BH2
# BDN , BD2
# BDN , BD2
# BDN , BD2
# BHN , BH2
# BHN , BH2
# BHN , BH2
# BHN , BH2
# BHN , BH2
# BHN , BH2
# BHN , BH2
# BHN , BH2
# BHN , BH2
# BHN , BH2
# BHN , BH2
# BHN , BH2
# BHN , BH2
# BHN , BH2
# BHN , BH2
# BDN , BD2
# BHN , BH2
# BHN , BH2
# BHN , BH2
# BHN , BH2
# BHN , BH2
# BHN , BH2
# BHN , BH2
# BHN , BH2
# BHN , BH2
# BHN , BH2
# BHN , BH2
# BHN , BH2
# BHN , BH2
# BHN , BH2
# BHN , BH2
# BHN , BH2
# BHN , BH2
# BHN , BH2
# BHN , BH2
# BHN , BH2
# BHN , BH2
# BHN , BH2
# BHN , BH2
# BHN , BH2
# BHN , BH2
# BHN , BH2
# BHN , BH2
# BHN , BH2
# BHN , BH2
# BHN , BH2
# BHN , BH2
# BHN , BH2
# BHN , BH2
# BDN , BD2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HHN , HH2
# HHN , HH2
# HHN , HH2
# HHN , HH2
# HHN , HH2
# HHN , HH2
# HHN , HH2
# HHN , HH2
# HHN , HH2
# HHN , HH2
# HHN , HH2
# HHN , HH2
# HHN , HH2
# HHN , HH2
# HHN , HH2
# HHN , HH2
# HHN , HH2
# HHN , HH2
# HHN , HH2
# HHN , HH2
# HHN , HH2
# HHN , HH2
# HHN , HH2
# HHN , HH2
# BHN , BH2
# BHN , BH2
# BHN , BH2
# HHN , HH2
# HHN , HH2
# HHN , HH2
# BHN , BH2
# BHN , BH2
# BHN , BH2
# HHN , HH2
# HHN , HH2
# HHN , HH2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# EHN , EH2
# EHN , EH2
# EHN , EH2
# EHN , EH2
# EHN , EH2
# EHN , EH2
# EHN , EH2
# EHN , EH2
# EHN , EH2
# EHN , EH2
# EHN , EH2
# EHN , EH2
# EHN , EH2
# EHN , EH2
# EHN , EH2
# EHN , EH2
# EHN , EH2
# EHN , EH2
# EHN , EH2
# EHN , EH2
# EHN , EH2
# EHN , EH2
# EHN , EH2
# EHN , EH2
# EHN , EH2
# EHN , EH2
# EHN , EH2
# EHN , EH2
# EHN , EH2
# EHN , EH2
# EHN , EH2
# EHN , EH2
# EHN , EH2
# EHN , EH2
# EHN , EH2
# EHN , EH2
# EHN , EH2
# EHN , EH2
# EHN , EH2
# EHN , EH2
# EHN , EH2
# EHN , EH2
# EHN , EH2
# EHN , EH2
# EHN , EH2
# HDN , HD2
# HDN , HD2
# HDN , HD2
# HDN , HD2
# ENN , EN2
# ENN , EN2
# ENN , EN2
# HHN , HH2
# HHN , HH2
# HHN , HH2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# ENN , EN2
# ENN , EN2
# ENN , EN2
# HHN , HH2
# HHN , HH2
# HHN , HH2
# BDN , BD2
# BDN , BD2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# ENN , EN2
# ENN , EN2
# ENN , EN2
# HHN , HH2
# HHN , HH2
# HHN , HH2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# ENN , EN2
# ENN , EN2
# ENN , EN2
# HHN , HH2
# HHN , HH2
# HHN , HH2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# ENN , EN2
# ENN , EN2
# ENN , EN2
# HHN , HH2
# HHN , HH2
# HHN , HH2
# BDN , BD2
# BDN , BD2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# ENN , EN2
# ENN , EN2
# ENN , EN2
# HHN , HH2
# HHN , HH2
# HHN , HH2
# ENN , EN2
# ENN , EN2
# ENN , EN2
# HHN , HH2
# HHN , HH2
# HHN , HH2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# ENN , EN2
# ENN , EN2
# ENN , EN2
# HHN , HH2
# HHN , HH2
# HHN , HH2
# ENN , EN2
# ENN , EN2
# ENN , EN2
# HHN , HH2
# HHN , HH2
# HHN , HH2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# ENN , EN2
# ENN , EN2
# ENN , EN2
# HHN , HH2
# HHN , HH2
# HHN , HH2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# ENN , EN2
# ENN , EN2
# ENN , EN2
# HHN , HH2
# HHN , HH2
# HHN , HH2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# ENN , EN2
# ENN , EN2
# ENN , EN2
# HHN , HH2
# HHN , HH2
# HHN , HH2
# ENN , EN2
# ENN , EN2
# ENN , EN2
# HHN , HH2
# HHN , HH2
# HHN , HH2
# BDN , BD2
# BDN , BD2
# ENN , EN2
# ENN , EN2
# ENN , EN2
# HHN , HH2
# HHN , HH2
# HHN , HH2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# ENN , EN2
# ENN , EN2
# ENN , EN2
# HHN , HH2
# HHN , HH2
# HHN , HH2
# BDN , BD2
# BDN , BD2
# ENN , EN2
# ENN , EN2
# ENN , EN2
# HHN , HH2
# HHN , HH2
# HHN , HH2
# ENN , EN2
# ENN , EN2
# ENN , EN2
# HHN , HH2
# HHN , HH2
# HHN , HH2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# ENN , EN2
# ENN , EN2
# ENN , EN2
# HHN , HH2
# HHN , HH2
# HHN , HH2
# ENN , EN2
# ENN , EN2
# ENN , EN2
# HHN , HH2
# HHN , HH2
# HHN , HH2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# ENN , EN2
# ENN , EN2
# ENN , EN2
# HHN , HH2
# HHN , HH2
# HHN , HH2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# ENN , EN2
# ENN , EN2
# ENN , EN2
# HHN , HH2
# HHN , HH2
# HHN , HH2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# ENN , EN2
# ENN , EN2
# ENN , EN2
# HHN , HH2
# HHN , HH2
# HHN , HH2
# BDN , BD2
# BDN , BD2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# ENN , EN2
# ENN , EN2
# ENN , EN2
# HHN , HH2
# HHN , HH2
# HHN , HH2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# ENN , EN2
# ENN , EN2
# ENN , EN2
# HHN , HH2
# HHN , HH2
# HHN , HH2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# ENN , EN2
# ENN , EN2
# ENN , EN2
# HHN , HH2
# HHN , HH2
# HHN , HH2
# ENN , EN2
# ENN , EN2
# ENN , EN2
# HHN , HH2
# HHN , HH2
# HHN , HH2
# ENN , EN2
# ENN , EN2
# ENN , EN2
# HHN , HH2
# HHN , HH2
# HHN , HH2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# ENN , EN2
# ENN , EN2
# ENN , EN2
# HHN , HH2
# HHN , HH2
# HHN , HH2
# ENN , EN2
# ENN , EN2
# ENN , EN2
# HHN , HH2
# HHN , HH2
# HHN , HH2
# ENN , EN2
# ENN , EN2
# ENN , EN2
# HHN , HH2
# HHN , HH2
# HHN , HH2
# ENN , EN2
# ENN , EN2
# ENN , EN2
# HHN , HH2
# HHN , HH2
# HHN , HH2
# ENN , EN2
# ENN , EN2
# ENN , EN2
# HHN , HH2
# HHN , HH2
# HHN , HH2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# ENN , EN2
# ENN , EN2
# ENN , EN2
# HHN , HH2
# HHN , HH2
# HHN , HH2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# ENN , EN2
# ENN , EN2
# ENN , EN2
# HHN , HH2
# HHN , HH2
# HHN , HH2
# BDN , BD2
# BDN , BD2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# ENN , EN2
# ENN , EN2
# ENN , EN2
# HHN , HH2
# HHN , HH2
# HHN , HH2
# ENN , EN2
# ENN , EN2
# ENN , EN2
# ENN , EN2
# ENN , EN2
# ENN , EN2
# EHN , EH2
# EHN , EH2
# ENN , EN2
# ENN , EN2
# ENN , EN2
# HHN , HH2
# HHN , HH2
# HHN , HH2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# ENN , EN2
# ENN , EN2
# ENN , EN2
# HHN , HH2
# HHN , HH2
# HHN , HH2
# ENN , EN2
# ENN , EN2
# ENN , EN2
# HHN , HH2
# HHN , HH2
# HHN , HH2
# EHN , EH2
# ENN , EN2
# ENN , EN2
# ENN , EN2
# EHN , EH2
# ENN , EN2
# ENN , EN2
# ENN , EN2
# HHN , HH2
# HHN , HH2
# HHN , HH2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# EHN , EH2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# ENN , EN2
# ENN , EN2
# ENN , EN2
# HHN , HH2
# HHN , HH2
# HHN , HH2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# ENN , EN2
# ENN , EN2
# ENN , EN2
# ENN , EN2
# ENN , EN2
# ENN , EN2
# HHN , HH2
# HHN , HH2
# HHN , HH2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# EHN , EH2
# HHN , HH2
# HHN , HH2
# HHN , HH2
# EHN , EH2
# ENN , EN2
# ENN , EN2
# ENN , EN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# ENN , EN2
# ENN , EN2
# ENN , EN2
# HHN , HH2
# HHN , HH2
# HHN , HH2
# EHN , EH2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# EHN , EH2
# ENN , EN2
# ENN , EN2
# ENN , EN2
# BHN , BH2
# BHN , BH2
# BHN , BH2
# ENN , EN2
# ENN , EN2
# ENN , EN2
# ENN , EN2
# ENN , EN2
# ENN , EN2
# HHN , HH2
# HHN , HH2
# HHN , HH2
# EHN , EH2
# ENN , EN2
# ENN , EN2
# ENN , EN2
# EHN , EH2
# ELN , EL2
# HHN , HH2
# HHN , HH2
# HHN , HH2
# ENN , EN2
# ENN , EN2
# ENN , EN2
# ENN , EN2
# ENN , EN2
# ENN , EN2
# HHN , HH2
# HHN , HH2
# HHN , HH2
# ENN , EN2
# ENN , EN2
# ENN , EN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# EHN , EH2
# ENN , EN2
# ENN , EN2
# ENN , EN2
# ENN , EN2
# ENN , EN2
# ENN , EN2
# HHN , HH2
# HHN , HH2
# HHN , HH2
# EHN , EH2
# ENN , EN2
# ENN , EN2
# ENN , EN2
# ENN , EN2
# ENN , EN2
# ENN , EN2
# HHN , HH2
# HHN , HH2
# HHN , HH2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# ENN , EN2
# ENN , EN2
# ENN , EN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# EHN , EH2
# EHN , EH2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# ENN , EN2
# ENN , EN2
# ENN , EN2
# EHN , EH2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# ENN , EN2
# ENN , EN2
# ENN , EN2
# HHN , HH2
# HHN , HH2
# HHN , HH2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# ENN , EN2
# ENN , EN2
# ENN , EN2
# EHN , EH2
# ENN , EN2
# ENN , EN2
# ENN , EN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# ENN , EN2
# ENN , EN2
# ENN , EN2
# HHN , HH2
# HHN , HH2
# HHN , HH2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# ENN , EN2
# ENN , EN2
# ENN , EN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# EHN , EH2
# ENN , EN2
# ENN , EN2
# ENN , EN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# ENN , EN2
# ENN , EN2
# ENN , EN2
# HHN , HH2
# HHN , HH2
# HHN , HH2
# EHN , EH2
# ELN , EL2
# HHN , HH2
# HHN , HH2
# HHN , HH2
# ENN , EN2
# ENN , EN2
# ENN , EN2
# HHN , HH2
# HHN , HH2
# HHN , HH2
# EHN , EH2
# ENN , EN2
# ENN , EN2
# ENN , EN2
# HHN , HH2
# HHN , HH2
# HHN , HH2
# ENN , EN2
# ENN , EN2
# ENN , EN2
# EHN , EH2
# EHN , EH2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# ENN , EN2
# ENN , EN2
# ENN , EN2
# HHN , HH2
# HHN , HH2
# HHN , HH2
# ENN , EN2
# ENN , EN2
# ENN , EN2
# EHN , EH2
# EHN , EH2
# ENN , EN2
# ENN , EN2
# ENN , EN2
# HHN , HH2
# HHN , HH2
# HHN , HH2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# ENN , EN2
# ENN , EN2
# ENN , EN2
# HHN , HH2
# HHN , HH2
# HHN , HH2
# EHN , EH2
# ENN , EN2
# ENN , EN2
# ENN , EN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# HNN , HN2
# ENN , EN2
# ENN , EN2
# ENN , EN2
# HHN , HH2
# HHN , HH2
# HHN , HH2

# %%
######## get distances btwn stations and events ###########
## make dataframe with station repeated, use this info for dl-ing waveforms
distances_all = []
sta_df_all = []
ev_mag_df_all = []
ev_origintime_df_all = []
ev_collecttime_all = []
ev_endtime_all = []
evdf_lat_all = []
evdf_lon_all = []
evdf_depth_all = []



for i_station in range(len(st_stas)):
    i_stlon = st_lons[i_station]
    i_stlat = st_lats[i_station]
    for event in eq_catalog:    
        ## add station name to long array:
        sta_df_all.append(st_stas[i_station])
        ## append event info:
        evdf_lat_all.append(event.origins[0].latitude)
        evdf_lon_all.append(event.origins[0].longitude)
        evdf_depth_all.append(event.origins[0].depth)
        
        ## get great circle distance between this event, and station:
        ij_grcircle_distance = gps2dist_azimuth(i_stlat, i_stlon, event.origins[0].latitude, event.origins[0].longitude)
        ij_grcircle_distance_km = ij_grcircle_distance[0]/1000
        ij_degrees = kilometers2degrees(ij_grcircle_distance_km)
        #ij_ttime = IRISclient.traveltime(model='iasp91', phases=['p'], evdepth=event.origins[0].depth, distkm=[ij_grcircle_distance_km], traveltimeonly=True)
        ## For each distance, assume 5 km/s average p-wave speed to get p-wave travel time:
        #ij_pwv_ttime = ij_grcircle_distance_km / 5.
        ij_pwv_ttime_allP = model.get_travel_times(source_depth_in_km=event.origins[0].depth/1000,
                                  distance_in_degree=ij_degrees,phase_list=["p","P"])
        ij_pwv_ttime = ij_pwv_ttime_allP[0].time
        
        ## start collecting waveform data 10 seconds before predicted p-wave arrival
        ev_collecttime_all.append(event.origins[0].time + (ij_pwv_ttime - 10))
        ## collect a total of 120 seconds
        ev_endtime_all.append(event.origins[0].time + (ij_pwv_ttime - 10) + 120)
        
        ## append:
        distances_all.append(ij_grcircle_distance_km)
        ev_mag_df_all.append(event.magnitudes[0].mag)
        ev_origintime_df_all.append(event.origins[0].time)
        
    print('st # ' + str(i_station) + ' of ' +str(len(st_stas)) + ' is done')
        
## Save then into a dictionary/dataframe, and sdave to file:
metadata_all = {'distance':distances_all, 'stations':sta_df_all, 'mag':ev_mag_df_all, 
                'origint':ev_origintime_df_all, 'collecttime':ev_collecttime_all, 'endtime':ev_endtime_all,
                'evlat':evdf_lat_all, 'evlon':evdf_lon_all, 'evdepth':evdf_depth_all}

metadata_all_df = pd.DataFrame(metadata_all)
metadata_all_df.to_csv((meta_dir + 'metadata_all.csv'),index=False)
# Out:
# st # 0 of 1185 is done
# st # 1 of 1185 is done
# st # 2 of 1185 is done
# st # 3 of 1185 is done
# st # 4 of 1185 is done
# st # 5 of 1185 is done
# st # 6 of 1185 is done
# st # 7 of 1185 is done
# st # 8 of 1185 is done
# st # 9 of 1185 is done
# st # 10 of 1185 is done
# st # 11 of 1185 is done
# st # 12 of 1185 is done
# st # 13 of 1185 is done
# st # 14 of 1185 is done
# st # 15 of 1185 is done
# st # 16 of 1185 is done
# st # 17 of 1185 is done
# st # 18 of 1185 is done
# st # 19 of 1185 is done
# st # 20 of 1185 is done
# st # 21 of 1185 is done
# st # 22 of 1185 is done
# st # 23 of 1185 is done
# st # 24 of 1185 is done
# st # 25 of 1185 is done
# st # 26 of 1185 is done
# st # 27 of 1185 is done
# st # 28 of 1185 is done
# st # 29 of 1185 is done
# st # 30 of 1185 is done
# st # 31 of 1185 is done
# st # 32 of 1185 is done
# st # 33 of 1185 is done
# st # 34 of 1185 is done
# st # 35 of 1185 is done
# st # 36 of 1185 is done
# st # 37 of 1185 is done
# st # 38 of 1185 is done
# st # 39 of 1185 is done
# st # 40 of 1185 is done
# st # 41 of 1185 is done
# st # 42 of 1185 is done
# st # 43 of 1185 is done
# st # 44 of 1185 is done
# st # 45 of 1185 is done
# st # 46 of 1185 is done
# st # 47 of 1185 is done
# st # 48 of 1185 is done
# st # 49 of 1185 is done
# st # 50 of 1185 is done
# st # 51 of 1185 is done
# st # 52 of 1185 is done
# st # 53 of 1185 is done
# st # 54 of 1185 is done
# st # 55 of 1185 is done
# st # 56 of 1185 is done
# st # 57 of 1185 is done
# st # 58 of 1185 is done
# st # 59 of 1185 is done
# st # 60 of 1185 is done
# st # 61 of 1185 is done
# st # 62 of 1185 is done
# st # 63 of 1185 is done
# st # 64 of 1185 is done
# st # 65 of 1185 is done
# st # 66 of 1185 is done
# st # 67 of 1185 is done
# st # 68 of 1185 is done
# st # 69 of 1185 is done
# st # 70 of 1185 is done
# st # 71 of 1185 is done
# st # 72 of 1185 is done
# st # 73 of 1185 is done
# st # 74 of 1185 is done
# st # 75 of 1185 is done
# st # 76 of 1185 is done
# st # 77 of 1185 is done
# st # 78 of 1185 is done
# st # 79 of 1185 is done
# st # 80 of 1185 is done
# st # 81 of 1185 is done
# st # 82 of 1185 is done
# st # 83 of 1185 is done
# st # 84 of 1185 is done
# st # 85 of 1185 is done
# st # 86 of 1185 is done
# st # 87 of 1185 is done
# st # 88 of 1185 is done
# st # 89 of 1185 is done
# st # 90 of 1185 is done
# st # 91 of 1185 is done
# st # 92 of 1185 is done
# st # 93 of 1185 is done
# st # 94 of 1185 is done
# st # 95 of 1185 is done
# st # 96 of 1185 is done
# st # 97 of 1185 is done
# st # 98 of 1185 is done
# st # 99 of 1185 is done
# st # 100 of 1185 is done
# st # 101 of 1185 is done
# st # 102 of 1185 is done
# st # 103 of 1185 is done
# st # 104 of 1185 is done
# st # 105 of 1185 is done
# st # 106 of 1185 is done
# st # 107 of 1185 is done
# st # 108 of 1185 is done
# st # 109 of 1185 is done
# st # 110 of 1185 is done
# st # 111 of 1185 is done
# st # 112 of 1185 is done
# st # 113 of 1185 is done
# st # 114 of 1185 is done
# st # 115 of 1185 is done
# st # 116 of 1185 is done
# st # 117 of 1185 is done
# st # 118 of 1185 is done
# st # 119 of 1185 is done
# st # 120 of 1185 is done
# st # 121 of 1185 is done
# st # 122 of 1185 is done
# st # 123 of 1185 is done
# st # 124 of 1185 is done
# st # 125 of 1185 is done
# st # 126 of 1185 is done
# st # 127 of 1185 is done
# st # 128 of 1185 is done
# st # 129 of 1185 is done
# st # 130 of 1185 is done
# st # 131 of 1185 is done
# st # 132 of 1185 is done
# st # 133 of 1185 is done
# st # 134 of 1185 is done
# st # 135 of 1185 is done
# st # 136 of 1185 is done
# st # 137 of 1185 is done
# st # 138 of 1185 is done
# st # 139 of 1185 is done
# st # 140 of 1185 is done
# st # 141 of 1185 is done
# st # 142 of 1185 is done
# st # 143 of 1185 is done
# st # 144 of 1185 is done
# st # 145 of 1185 is done
# st # 146 of 1185 is done
# st # 147 of 1185 is done
# st # 148 of 1185 is done
# st # 149 of 1185 is done
# st # 150 of 1185 is done
# st # 151 of 1185 is done
# st # 152 of 1185 is done
# st # 153 of 1185 is done
# st # 154 of 1185 is done
# st # 155 of 1185 is done
# st # 156 of 1185 is done
# st # 157 of 1185 is done
# st # 158 of 1185 is done
# st # 159 of 1185 is done
# st # 160 of 1185 is done
# st # 161 of 1185 is done
# st # 162 of 1185 is done
# st # 163 of 1185 is done
# st # 164 of 1185 is done
# st # 165 of 1185 is done
# st # 166 of 1185 is done
# st # 167 of 1185 is done
# st # 168 of 1185 is done
# st # 169 of 1185 is done
# st # 170 of 1185 is done
# st # 171 of 1185 is done
# st # 172 of 1185 is done
# st # 173 of 1185 is done
# st # 174 of 1185 is done
# st # 175 of 1185 is done
# st # 176 of 1185 is done
# st # 177 of 1185 is done
# st # 178 of 1185 is done
# st # 179 of 1185 is done
# st # 180 of 1185 is done
# st # 181 of 1185 is done
# st # 182 of 1185 is done
# st # 183 of 1185 is done
# st # 184 of 1185 is done
# st # 185 of 1185 is done
# st # 186 of 1185 is done
# st # 187 of 1185 is done
# st # 188 of 1185 is done
# st # 189 of 1185 is done
# st # 190 of 1185 is done
# st # 191 of 1185 is done
# st # 192 of 1185 is done
# st # 193 of 1185 is done
# st # 194 of 1185 is done
# st # 195 of 1185 is done
# st # 196 of 1185 is done
# st # 197 of 1185 is done
# st # 198 of 1185 is done
# st # 199 of 1185 is done
# st # 200 of 1185 is done
# st # 201 of 1185 is done
# st # 202 of 1185 is done
# st # 203 of 1185 is done
# st # 204 of 1185 is done
# st # 205 of 1185 is done
# st # 206 of 1185 is done
# st # 207 of 1185 is done
# st # 208 of 1185 is done
# st # 209 of 1185 is done
# st # 210 of 1185 is done
# st # 211 of 1185 is done
# st # 212 of 1185 is done
# st # 213 of 1185 is done
# st # 214 of 1185 is done
# st # 215 of 1185 is done
# st # 216 of 1185 is done
# st # 217 of 1185 is done
# st # 218 of 1185 is done
# st # 219 of 1185 is done
# st # 220 of 1185 is done
# st # 221 of 1185 is done
# st # 222 of 1185 is done
# st # 223 of 1185 is done
# st # 224 of 1185 is done
# st # 225 of 1185 is done
# st # 226 of 1185 is done
# st # 227 of 1185 is done
# st # 228 of 1185 is done
# st # 229 of 1185 is done
# st # 230 of 1185 is done
# st # 231 of 1185 is done
# st # 232 of 1185 is done
# st # 233 of 1185 is done
# st # 234 of 1185 is done
# st # 235 of 1185 is done
# st # 236 of 1185 is done
# st # 237 of 1185 is done
# st # 238 of 1185 is done
# st # 239 of 1185 is done
# st # 240 of 1185 is done
# st # 241 of 1185 is done
# st # 242 of 1185 is done
# st # 243 of 1185 is done
# st # 244 of 1185 is done
# st # 245 of 1185 is done
# st # 246 of 1185 is done
# st # 247 of 1185 is done
# st # 248 of 1185 is done
# st # 249 of 1185 is done
# st # 250 of 1185 is done
# st # 251 of 1185 is done
# st # 252 of 1185 is done
# st # 253 of 1185 is done
# st # 254 of 1185 is done
# st # 255 of 1185 is done
# st # 256 of 1185 is done
# st # 257 of 1185 is done
# st # 258 of 1185 is done
# st # 259 of 1185 is done
# st # 260 of 1185 is done
# st # 261 of 1185 is done
# st # 262 of 1185 is done
# st # 263 of 1185 is done
# st # 264 of 1185 is done
# st # 265 of 1185 is done
# st # 266 of 1185 is done
# st # 267 of 1185 is done
# st # 268 of 1185 is done
# st # 269 of 1185 is done
# st # 270 of 1185 is done
# st # 271 of 1185 is done
# st # 272 of 1185 is done
# st # 273 of 1185 is done
# st # 274 of 1185 is done
# st # 275 of 1185 is done
# st # 276 of 1185 is done
# st # 277 of 1185 is done
# st # 278 of 1185 is done
# st # 279 of 1185 is done
# st # 280 of 1185 is done
# st # 281 of 1185 is done
# st # 282 of 1185 is done
# st # 283 of 1185 is done
# st # 284 of 1185 is done
# st # 285 of 1185 is done
# st # 286 of 1185 is done
# st # 287 of 1185 is done
# st # 288 of 1185 is done
# st # 289 of 1185 is done
# st # 290 of 1185 is done
# st # 291 of 1185 is done
# st # 292 of 1185 is done
# st # 293 of 1185 is done
# st # 294 of 1185 is done
# st # 295 of 1185 is done
# st # 296 of 1185 is done
# st # 297 of 1185 is done
# st # 298 of 1185 is done
# st # 299 of 1185 is done
# st # 300 of 1185 is done
# st # 301 of 1185 is done
# st # 302 of 1185 is done
# st # 303 of 1185 is done
# st # 304 of 1185 is done
# st # 305 of 1185 is done
# st # 306 of 1185 is done
# st # 307 of 1185 is done
# st # 308 of 1185 is done
# st # 309 of 1185 is done
# st # 310 of 1185 is done
# st # 311 of 1185 is done
# st # 312 of 1185 is done
# st # 313 of 1185 is done
# st # 314 of 1185 is done
# st # 315 of 1185 is done
# st # 316 of 1185 is done
# st # 317 of 1185 is done
# st # 318 of 1185 is done
# st # 319 of 1185 is done
# st # 320 of 1185 is done
# st # 321 of 1185 is done
# st # 322 of 1185 is done
# st # 323 of 1185 is done
# st # 324 of 1185 is done
# st # 325 of 1185 is done
# st # 326 of 1185 is done
# st # 327 of 1185 is done
# st # 328 of 1185 is done
# st # 329 of 1185 is done
# st # 330 of 1185 is done
# st # 331 of 1185 is done
# st # 332 of 1185 is done
# st # 333 of 1185 is done
# st # 334 of 1185 is done
# st # 335 of 1185 is done
# st # 336 of 1185 is done
# st # 337 of 1185 is done
# st # 338 of 1185 is done
# st # 339 of 1185 is done
# st # 340 of 1185 is done
# st # 341 of 1185 is done
# st # 342 of 1185 is done
# st # 343 of 1185 is done
# st # 344 of 1185 is done
# st # 345 of 1185 is done
# st # 346 of 1185 is done
# st # 347 of 1185 is done
# st # 348 of 1185 is done
# st # 349 of 1185 is done
# st # 350 of 1185 is done
# st # 351 of 1185 is done
# st # 352 of 1185 is done
# st # 353 of 1185 is done
# st # 354 of 1185 is done
# st # 355 of 1185 is done
# st # 356 of 1185 is done
# st # 357 of 1185 is done
# st # 358 of 1185 is done
# st # 359 of 1185 is done
# st # 360 of 1185 is done
# st # 361 of 1185 is done
# st # 362 of 1185 is done
# st # 363 of 1185 is done
# st # 364 of 1185 is done
# st # 365 of 1185 is done
# st # 366 of 1185 is done
# st # 367 of 1185 is done
# st # 368 of 1185 is done
# st # 369 of 1185 is done
# st # 370 of 1185 is done
# st # 371 of 1185 is done
# st # 372 of 1185 is done
# st # 373 of 1185 is done
# st # 374 of 1185 is done
# st # 375 of 1185 is done
# st # 376 of 1185 is done
# st # 377 of 1185 is done
# st # 378 of 1185 is done
# st # 379 of 1185 is done
# st # 380 of 1185 is done
# st # 381 of 1185 is done
# st # 382 of 1185 is done
# st # 383 of 1185 is done
# st # 384 of 1185 is done
# st # 385 of 1185 is done
# st # 386 of 1185 is done
# st # 387 of 1185 is done
# st # 388 of 1185 is done
# st # 389 of 1185 is done
# st # 390 of 1185 is done
# st # 391 of 1185 is done
# st # 392 of 1185 is done
# st # 393 of 1185 is done
# st # 394 of 1185 is done
# st # 395 of 1185 is done
# st # 396 of 1185 is done
# st # 397 of 1185 is done
# st # 398 of 1185 is done
# st # 399 of 1185 is done
# st # 400 of 1185 is done
# st # 401 of 1185 is done
# st # 402 of 1185 is done
# st # 403 of 1185 is done
# st # 404 of 1185 is done
# st # 405 of 1185 is done
# st # 406 of 1185 is done
# st # 407 of 1185 is done
# st # 408 of 1185 is done
# st # 409 of 1185 is done
# st # 410 of 1185 is done
# st # 411 of 1185 is done
# st # 412 of 1185 is done
# st # 413 of 1185 is done
# st # 414 of 1185 is done
# st # 415 of 1185 is done
# st # 416 of 1185 is done
# st # 417 of 1185 is done
# st # 418 of 1185 is done
# st # 419 of 1185 is done
# st # 420 of 1185 is done
# st # 421 of 1185 is done
# st # 422 of 1185 is done
# st # 423 of 1185 is done
# st # 424 of 1185 is done
# st # 425 of 1185 is done
# st # 426 of 1185 is done
# st # 427 of 1185 is done
# st # 428 of 1185 is done
# st # 429 of 1185 is done
# st # 430 of 1185 is done
# st # 431 of 1185 is done
# st # 432 of 1185 is done
# st # 433 of 1185 is done
# st # 434 of 1185 is done
# st # 435 of 1185 is done
# st # 436 of 1185 is done
# st # 437 of 1185 is done
# st # 438 of 1185 is done
# st # 439 of 1185 is done
# st # 440 of 1185 is done
# st # 441 of 1185 is done
# st # 442 of 1185 is done
# st # 443 of 1185 is done
# st # 444 of 1185 is done
# st # 445 of 1185 is done
# st # 446 of 1185 is done
# st # 447 of 1185 is done
# st # 448 of 1185 is done
# st # 449 of 1185 is done
# st # 450 of 1185 is done
# st # 451 of 1185 is done
# st # 452 of 1185 is done
# st # 453 of 1185 is done
# st # 454 of 1185 is done
# st # 455 of 1185 is done
# st # 456 of 1185 is done
# st # 457 of 1185 is done
# st # 458 of 1185 is done
# st # 459 of 1185 is done
# st # 460 of 1185 is done
# st # 461 of 1185 is done
# st # 462 of 1185 is done
# st # 463 of 1185 is done
# st # 464 of 1185 is done
# st # 465 of 1185 is done
# st # 466 of 1185 is done
# st # 467 of 1185 is done
# st # 468 of 1185 is done
# st # 469 of 1185 is done
# st # 470 of 1185 is done
# st # 471 of 1185 is done
# st # 472 of 1185 is done
# st # 473 of 1185 is done
# st # 474 of 1185 is done
# st # 475 of 1185 is done
# st # 476 of 1185 is done
# st # 477 of 1185 is done
# st # 478 of 1185 is done
# st # 479 of 1185 is done
# st # 480 of 1185 is done
# st # 481 of 1185 is done
# st # 482 of 1185 is done
# st # 483 of 1185 is done
# st # 484 of 1185 is done
# st # 485 of 1185 is done
# st # 486 of 1185 is done
# st # 487 of 1185 is done
# st # 488 of 1185 is done
# st # 489 of 1185 is done
# st # 490 of 1185 is done
# st # 491 of 1185 is done
# st # 492 of 1185 is done
# st # 493 of 1185 is done
# st # 494 of 1185 is done
# st # 495 of 1185 is done
# st # 496 of 1185 is done
# st # 497 of 1185 is done
# st # 498 of 1185 is done
# st # 499 of 1185 is done
# st # 500 of 1185 is done
# st # 501 of 1185 is done
# st # 502 of 1185 is done
# st # 503 of 1185 is done
# st # 504 of 1185 is done
# st # 505 of 1185 is done
# st # 506 of 1185 is done
# st # 507 of 1185 is done
# st # 508 of 1185 is done
# st # 509 of 1185 is done
# st # 510 of 1185 is done
# st # 511 of 1185 is done
# st # 512 of 1185 is done
# st # 513 of 1185 is done
# st # 514 of 1185 is done
# st # 515 of 1185 is done
# st # 516 of 1185 is done
# st # 517 of 1185 is done
# st # 518 of 1185 is done
# st # 519 of 1185 is done
# st # 520 of 1185 is done
# st # 521 of 1185 is done
# st # 522 of 1185 is done
# st # 523 of 1185 is done
# st # 524 of 1185 is done
# st # 525 of 1185 is done
# st # 526 of 1185 is done
# st # 527 of 1185 is done
# st # 528 of 1185 is done
# st # 529 of 1185 is done
# st # 530 of 1185 is done
# st # 531 of 1185 is done
# st # 532 of 1185 is done
# st # 533 of 1185 is done
# st # 534 of 1185 is done
# st # 535 of 1185 is done
# st # 536 of 1185 is done
# st # 537 of 1185 is done
# st # 538 of 1185 is done
# st # 539 of 1185 is done
# st # 540 of 1185 is done
# st # 541 of 1185 is done
# st # 542 of 1185 is done
# st # 543 of 1185 is done
# st # 544 of 1185 is done
# st # 545 of 1185 is done
# st # 546 of 1185 is done
# st # 547 of 1185 is done
# st # 548 of 1185 is done
# st # 549 of 1185 is done
# st # 550 of 1185 is done
# st # 551 of 1185 is done
# st # 552 of 1185 is done
# st # 553 of 1185 is done
# st # 554 of 1185 is done
# st # 555 of 1185 is done
# st # 556 of 1185 is done
# st # 557 of 1185 is done
# st # 558 of 1185 is done
# st # 559 of 1185 is done
# st # 560 of 1185 is done
# st # 561 of 1185 is done
# st # 562 of 1185 is done
# st # 563 of 1185 is done
# st # 564 of 1185 is done
# st # 565 of 1185 is done
# st # 566 of 1185 is done
# st # 567 of 1185 is done
# st # 568 of 1185 is done
# st # 569 of 1185 is done
# st # 570 of 1185 is done
# st # 571 of 1185 is done
# st # 572 of 1185 is done
# st # 573 of 1185 is done
# st # 574 of 1185 is done
# st # 575 of 1185 is done
# st # 576 of 1185 is done
# st # 577 of 1185 is done
# st # 578 of 1185 is done
# st # 579 of 1185 is done
# st # 580 of 1185 is done
# st # 581 of 1185 is done
# st # 582 of 1185 is done
# st # 583 of 1185 is done
# st # 584 of 1185 is done
# st # 585 of 1185 is done
# st # 586 of 1185 is done
# st # 587 of 1185 is done
# st # 588 of 1185 is done
# st # 589 of 1185 is done
# st # 590 of 1185 is done
# st # 591 of 1185 is done
# st # 592 of 1185 is done
# st # 593 of 1185 is done
# st # 594 of 1185 is done
# st # 595 of 1185 is done
# st # 596 of 1185 is done
# st # 597 of 1185 is done
# st # 598 of 1185 is done
# st # 599 of 1185 is done
# st # 600 of 1185 is done
# st # 601 of 1185 is done
# st # 602 of 1185 is done
# st # 603 of 1185 is done
# st # 604 of 1185 is done
# st # 605 of 1185 is done
# st # 606 of 1185 is done
# st # 607 of 1185 is done
# st # 608 of 1185 is done
# st # 609 of 1185 is done
# st # 610 of 1185 is done
# st # 611 of 1185 is done
# st # 612 of 1185 is done
# st # 613 of 1185 is done
# st # 614 of 1185 is done
# st # 615 of 1185 is done
# st # 616 of 1185 is done
# st # 617 of 1185 is done
# st # 618 of 1185 is done
# st # 619 of 1185 is done
# st # 620 of 1185 is done
# st # 621 of 1185 is done
# st # 622 of 1185 is done
# st # 623 of 1185 is done
# st # 624 of 1185 is done
# st # 625 of 1185 is done
# st # 626 of 1185 is done
# st # 627 of 1185 is done
# st # 628 of 1185 is done
# st # 629 of 1185 is done
# st # 630 of 1185 is done
# st # 631 of 1185 is done
# st # 632 of 1185 is done
# st # 633 of 1185 is done
# st # 634 of 1185 is done
# st # 635 of 1185 is done
# st # 636 of 1185 is done
# st # 637 of 1185 is done
# st # 638 of 1185 is done
# st # 639 of 1185 is done
# st # 640 of 1185 is done
# st # 641 of 1185 is done
# st # 642 of 1185 is done
# st # 643 of 1185 is done
# st # 644 of 1185 is done
# st # 645 of 1185 is done
# st # 646 of 1185 is done
# st # 647 of 1185 is done
# st # 648 of 1185 is done
# st # 649 of 1185 is done
# st # 650 of 1185 is done
# st # 651 of 1185 is done
# st # 652 of 1185 is done
# st # 653 of 1185 is done
# st # 654 of 1185 is done
# st # 655 of 1185 is done
# st # 656 of 1185 is done
# st # 657 of 1185 is done
# st # 658 of 1185 is done
# st # 659 of 1185 is done
# st # 660 of 1185 is done
# st # 661 of 1185 is done
# st # 662 of 1185 is done
# st # 663 of 1185 is done
# st # 664 of 1185 is done
# st # 665 of 1185 is done
# st # 666 of 1185 is done
# st # 667 of 1185 is done
# st # 668 of 1185 is done
# st # 669 of 1185 is done
# st # 670 of 1185 is done
# st # 671 of 1185 is done
# st # 672 of 1185 is done
# st # 673 of 1185 is done
# st # 674 of 1185 is done
# st # 675 of 1185 is done
# st # 676 of 1185 is done
# st # 677 of 1185 is done
# st # 678 of 1185 is done
# st # 679 of 1185 is done
# st # 680 of 1185 is done
# st # 681 of 1185 is done
# st # 682 of 1185 is done
# st # 683 of 1185 is done
# st # 684 of 1185 is done
# st # 685 of 1185 is done
# st # 686 of 1185 is done
# st # 687 of 1185 is done
# st # 688 of 1185 is done
# st # 689 of 1185 is done
# st # 690 of 1185 is done
# st # 691 of 1185 is done
# st # 692 of 1185 is done
# st # 693 of 1185 is done
# st # 694 of 1185 is done
# st # 695 of 1185 is done
# st # 696 of 1185 is done
# st # 697 of 1185 is done
# st # 698 of 1185 is done
# st # 699 of 1185 is done
# st # 700 of 1185 is done
# st # 701 of 1185 is done
# st # 702 of 1185 is done
# st # 703 of 1185 is done
# st # 704 of 1185 is done
# st # 705 of 1185 is done
# st # 706 of 1185 is done
# st # 707 of 1185 is done
# st # 708 of 1185 is done
# st # 709 of 1185 is done
# st # 710 of 1185 is done
# st # 711 of 1185 is done
# st # 712 of 1185 is done
# st # 713 of 1185 is done
# st # 714 of 1185 is done
# st # 715 of 1185 is done
# st # 716 of 1185 is done
# st # 717 of 1185 is done
# st # 718 of 1185 is done
# st # 719 of 1185 is done
# st # 720 of 1185 is done
# st # 721 of 1185 is done
# st # 722 of 1185 is done
# st # 723 of 1185 is done
# st # 724 of 1185 is done
# st # 725 of 1185 is done
# st # 726 of 1185 is done
# st # 727 of 1185 is done
# st # 728 of 1185 is done
# st # 729 of 1185 is done
# st # 730 of 1185 is done
# st # 731 of 1185 is done
# st # 732 of 1185 is done
# st # 733 of 1185 is done
# st # 734 of 1185 is done
# st # 735 of 1185 is done
# st # 736 of 1185 is done
# st # 737 of 1185 is done
# st # 738 of 1185 is done
# st # 739 of 1185 is done
# st # 740 of 1185 is done
# st # 741 of 1185 is done
# st # 742 of 1185 is done
# st # 743 of 1185 is done
# st # 744 of 1185 is done
# st # 745 of 1185 is done
# st # 746 of 1185 is done
# st # 747 of 1185 is done
# st # 748 of 1185 is done
# st # 749 of 1185 is done
# st # 750 of 1185 is done
# st # 751 of 1185 is done
# st # 752 of 1185 is done
# st # 753 of 1185 is done
# st # 754 of 1185 is done
# st # 755 of 1185 is done
# st # 756 of 1185 is done
# st # 757 of 1185 is done
# st # 758 of 1185 is done
# st # 759 of 1185 is done
# st # 760 of 1185 is done
# st # 761 of 1185 is done
# st # 762 of 1185 is done
# st # 763 of 1185 is done
# st # 764 of 1185 is done
# st # 765 of 1185 is done
# st # 766 of 1185 is done
# st # 767 of 1185 is done
# st # 768 of 1185 is done
# st # 769 of 1185 is done
# st # 770 of 1185 is done
# st # 771 of 1185 is done
# st # 772 of 1185 is done
# st # 773 of 1185 is done
# st # 774 of 1185 is done
# st # 775 of 1185 is done
# st # 776 of 1185 is done
# st # 777 of 1185 is done
# st # 778 of 1185 is done
# st # 779 of 1185 is done
# st # 780 of 1185 is done
# st # 781 of 1185 is done
# st # 782 of 1185 is done
# st # 783 of 1185 is done
# st # 784 of 1185 is done
# st # 785 of 1185 is done
# st # 786 of 1185 is done
# st # 787 of 1185 is done
# st # 788 of 1185 is done
# st # 789 of 1185 is done
# st # 790 of 1185 is done
# st # 791 of 1185 is done
# st # 792 of 1185 is done
# st # 793 of 1185 is done
# st # 794 of 1185 is done
# st # 795 of 1185 is done
# st # 796 of 1185 is done
# st # 797 of 1185 is done
# st # 798 of 1185 is done
# st # 799 of 1185 is done
# st # 800 of 1185 is done
# st # 801 of 1185 is done
# st # 802 of 1185 is done
# st # 803 of 1185 is done
# st # 804 of 1185 is done
# st # 805 of 1185 is done
# st # 806 of 1185 is done
# st # 807 of 1185 is done
# st # 808 of 1185 is done
# st # 809 of 1185 is done
# st # 810 of 1185 is done
# st # 811 of 1185 is done
# st # 812 of 1185 is done
# st # 813 of 1185 is done
# st # 814 of 1185 is done
# st # 815 of 1185 is done
# st # 816 of 1185 is done
# st # 817 of 1185 is done
# st # 818 of 1185 is done
# st # 819 of 1185 is done
# st # 820 of 1185 is done
# st # 821 of 1185 is done
# st # 822 of 1185 is done
# st # 823 of 1185 is done
# st # 824 of 1185 is done
# st # 825 of 1185 is done
# st # 826 of 1185 is done
# st # 827 of 1185 is done
# st # 828 of 1185 is done
# st # 829 of 1185 is done
# st # 830 of 1185 is done
# st # 831 of 1185 is done
# st # 832 of 1185 is done
# st # 833 of 1185 is done
# st # 834 of 1185 is done
# st # 835 of 1185 is done
# st # 836 of 1185 is done
# st # 837 of 1185 is done
# st # 838 of 1185 is done
# st # 839 of 1185 is done
# st # 840 of 1185 is done
# st # 841 of 1185 is done
# st # 842 of 1185 is done
# st # 843 of 1185 is done
# st # 844 of 1185 is done
# st # 845 of 1185 is done
# st # 846 of 1185 is done
# st # 847 of 1185 is done
# st # 848 of 1185 is done
# st # 849 of 1185 is done
# st # 850 of 1185 is done
# st # 851 of 1185 is done
# st # 852 of 1185 is done
# st # 853 of 1185 is done
# st # 854 of 1185 is done
# st # 855 of 1185 is done
# st # 856 of 1185 is done
# st # 857 of 1185 is done
# st # 858 of 1185 is done
# st # 859 of 1185 is done
# st # 860 of 1185 is done
# st # 861 of 1185 is done
# st # 862 of 1185 is done
# st # 863 of 1185 is done
# st # 864 of 1185 is done
# st # 865 of 1185 is done
# st # 866 of 1185 is done
# st # 867 of 1185 is done
# st # 868 of 1185 is done
# st # 869 of 1185 is done
# st # 870 of 1185 is done
# st # 871 of 1185 is done
# st # 872 of 1185 is done
# st # 873 of 1185 is done
# st # 874 of 1185 is done
# st # 875 of 1185 is done
# st # 876 of 1185 is done
# st # 877 of 1185 is done
# st # 878 of 1185 is done
# st # 879 of 1185 is done
# st # 880 of 1185 is done
# st # 881 of 1185 is done
# st # 882 of 1185 is done
# st # 883 of 1185 is done
# st # 884 of 1185 is done
# st # 885 of 1185 is done
# st # 886 of 1185 is done
# st # 887 of 1185 is done
# st # 888 of 1185 is done
# st # 889 of 1185 is done
# st # 890 of 1185 is done
# st # 891 of 1185 is done
# st # 892 of 1185 is done
# st # 893 of 1185 is done
# st # 894 of 1185 is done
# st # 895 of 1185 is done
# st # 896 of 1185 is done
# st # 897 of 1185 is done
# st # 898 of 1185 is done
# st # 899 of 1185 is done
# st # 900 of 1185 is done
# st # 901 of 1185 is done
# st # 902 of 1185 is done
# st # 903 of 1185 is done
# st # 904 of 1185 is done
# st # 905 of 1185 is done
# st # 906 of 1185 is done
# st # 907 of 1185 is done
# st # 908 of 1185 is done
# st # 909 of 1185 is done
# st # 910 of 1185 is done
# st # 911 of 1185 is done
# st # 912 of 1185 is done
# st # 913 of 1185 is done
# st # 914 of 1185 is done
# st # 915 of 1185 is done
# st # 916 of 1185 is done
# st # 917 of 1185 is done
# st # 918 of 1185 is done
# st # 919 of 1185 is done
# st # 920 of 1185 is done
# st # 921 of 1185 is done
# st # 922 of 1185 is done
# st # 923 of 1185 is done
# st # 924 of 1185 is done
# st # 925 of 1185 is done
# st # 926 of 1185 is done
# st # 927 of 1185 is done
# st # 928 of 1185 is done
# st # 929 of 1185 is done
# st # 930 of 1185 is done
# st # 931 of 1185 is done
# st # 932 of 1185 is done
# st # 933 of 1185 is done
# st # 934 of 1185 is done
# st # 935 of 1185 is done
# st # 936 of 1185 is done
# st # 937 of 1185 is done
# st # 938 of 1185 is done
# st # 939 of 1185 is done
# st # 940 of 1185 is done
# st # 941 of 1185 is done
# st # 942 of 1185 is done
# st # 943 of 1185 is done
# st # 944 of 1185 is done
# st # 945 of 1185 is done
# st # 946 of 1185 is done
# st # 947 of 1185 is done
# st # 948 of 1185 is done
# st # 949 of 1185 is done
# st # 950 of 1185 is done
# st # 951 of 1185 is done
# st # 952 of 1185 is done
# st # 953 of 1185 is done
# st # 954 of 1185 is done
# st # 955 of 1185 is done
# st # 956 of 1185 is done
# st # 957 of 1185 is done
# st # 958 of 1185 is done
# st # 959 of 1185 is done
# st # 960 of 1185 is done
# st # 961 of 1185 is done
# st # 962 of 1185 is done
# st # 963 of 1185 is done
# st # 964 of 1185 is done
# st # 965 of 1185 is done
# st # 966 of 1185 is done
# st # 967 of 1185 is done
# st # 968 of 1185 is done
# st # 969 of 1185 is done
# st # 970 of 1185 is done
# st # 971 of 1185 is done
# st # 972 of 1185 is done
# st # 973 of 1185 is done
# st # 974 of 1185 is done
# st # 975 of 1185 is done
# st # 976 of 1185 is done
# st # 977 of 1185 is done
# st # 978 of 1185 is done
# st # 979 of 1185 is done
# st # 980 of 1185 is done
# st # 981 of 1185 is done
# st # 982 of 1185 is done
# st # 983 of 1185 is done
# st # 984 of 1185 is done
# st # 985 of 1185 is done
# st # 986 of 1185 is done
# st # 987 of 1185 is done
# st # 988 of 1185 is done
# st # 989 of 1185 is done
# st # 990 of 1185 is done
# st # 991 of 1185 is done
# st # 992 of 1185 is done
# st # 993 of 1185 is done
# st # 994 of 1185 is done
# st # 995 of 1185 is done
# st # 996 of 1185 is done
# st # 997 of 1185 is done
# st # 998 of 1185 is done
# st # 999 of 1185 is done
# st # 1000 of 1185 is done
# st # 1001 of 1185 is done
# st # 1002 of 1185 is done
# st # 1003 of 1185 is done
# st # 1004 of 1185 is done
# st # 1005 of 1185 is done
# st # 1006 of 1185 is done
# st # 1007 of 1185 is done
# st # 1008 of 1185 is done
# st # 1009 of 1185 is done
# st # 1010 of 1185 is done
# st # 1011 of 1185 is done
# st # 1012 of 1185 is done
# st # 1013 of 1185 is done
# st # 1014 of 1185 is done
# st # 1015 of 1185 is done
# st # 1016 of 1185 is done
# st # 1017 of 1185 is done
# st # 1018 of 1185 is done
# st # 1019 of 1185 is done
# st # 1020 of 1185 is done
# st # 1021 of 1185 is done
# st # 1022 of 1185 is done
# st # 1023 of 1185 is done
# st # 1024 of 1185 is done
# st # 1025 of 1185 is done
# st # 1026 of 1185 is done
# st # 1027 of 1185 is done
# st # 1028 of 1185 is done
# st # 1029 of 1185 is done
# st # 1030 of 1185 is done
# st # 1031 of 1185 is done
# st # 1032 of 1185 is done
# st # 1033 of 1185 is done
# st # 1034 of 1185 is done
# st # 1035 of 1185 is done
# st # 1036 of 1185 is done
# st # 1037 of 1185 is done
# st # 1038 of 1185 is done
# st # 1039 of 1185 is done
# st # 1040 of 1185 is done
# st # 1041 of 1185 is done
# st # 1042 of 1185 is done
# st # 1043 of 1185 is done
# st # 1044 of 1185 is done
# st # 1045 of 1185 is done
# st # 1046 of 1185 is done
# st # 1047 of 1185 is done
# st # 1048 of 1185 is done
# st # 1049 of 1185 is done
# st # 1050 of 1185 is done
# st # 1051 of 1185 is done
# st # 1052 of 1185 is done
# st # 1053 of 1185 is done
# st # 1054 of 1185 is done
# st # 1055 of 1185 is done
# st # 1056 of 1185 is done
# st # 1057 of 1185 is done
# st # 1058 of 1185 is done
# st # 1059 of 1185 is done
# st # 1060 of 1185 is done
# st # 1061 of 1185 is done
# st # 1062 of 1185 is done
# st # 1063 of 1185 is done
# st # 1064 of 1185 is done
# st # 1065 of 1185 is done
# st # 1066 of 1185 is done
# st # 1067 of 1185 is done
# st # 1068 of 1185 is done
# st # 1069 of 1185 is done
# st # 1070 of 1185 is done
# st # 1071 of 1185 is done
# st # 1072 of 1185 is done
# st # 1073 of 1185 is done
# st # 1074 of 1185 is done
# st # 1075 of 1185 is done
# st # 1076 of 1185 is done
# st # 1077 of 1185 is done
# st # 1078 of 1185 is done
# st # 1079 of 1185 is done
# st # 1080 of 1185 is done
# st # 1081 of 1185 is done
# st # 1082 of 1185 is done
# st # 1083 of 1185 is done
# st # 1084 of 1185 is done
# st # 1085 of 1185 is done
# st # 1086 of 1185 is done
# st # 1087 of 1185 is done
# st # 1088 of 1185 is done
# st # 1089 of 1185 is done
# st # 1090 of 1185 is done
# st # 1091 of 1185 is done
# st # 1092 of 1185 is done
# st # 1093 of 1185 is done
# st # 1094 of 1185 is done
# st # 1095 of 1185 is done
# st # 1096 of 1185 is done
# st # 1097 of 1185 is done
# st # 1098 of 1185 is done
# st # 1099 of 1185 is done
# st # 1100 of 1185 is done
# st # 1101 of 1185 is done
# st # 1102 of 1185 is done
# st # 1103 of 1185 is done
# st # 1104 of 1185 is done
# st # 1105 of 1185 is done
# st # 1106 of 1185 is done
# st # 1107 of 1185 is done
# st # 1108 of 1185 is done
# st # 1109 of 1185 is done
# st # 1110 of 1185 is done
# st # 1111 of 1185 is done
# st # 1112 of 1185 is done
# st # 1113 of 1185 is done
# st # 1114 of 1185 is done
# st # 1115 of 1185 is done
# st # 1116 of 1185 is done
# st # 1117 of 1185 is done
# st # 1118 of 1185 is done
# st # 1119 of 1185 is done
# st # 1120 of 1185 is done
# st # 1121 of 1185 is done
# st # 1122 of 1185 is done
# st # 1123 of 1185 is done
# st # 1124 of 1185 is done
# st # 1125 of 1185 is done
# st # 1126 of 1185 is done
# st # 1127 of 1185 is done
# st # 1128 of 1185 is done
# st # 1129 of 1185 is done
# st # 1130 of 1185 is done
# st # 1131 of 1185 is done
# st # 1132 of 1185 is done
# st # 1133 of 1185 is done
# st # 1134 of 1185 is done
# st # 1135 of 1185 is done
# st # 1136 of 1185 is done
# st # 1137 of 1185 is done
# st # 1138 of 1185 is done
# st # 1139 of 1185 is done
# st # 1140 of 1185 is done
# st # 1141 of 1185 is done
# st # 1142 of 1185 is done
# st # 1143 of 1185 is done
# st # 1144 of 1185 is done
# st # 1145 of 1185 is done
# st # 1146 of 1185 is done
# st # 1147 of 1185 is done
# st # 1148 of 1185 is done
# st # 1149 of 1185 is done
# st # 1150 of 1185 is done
# st # 1151 of 1185 is done
# st # 1152 of 1185 is done
# st # 1153 of 1185 is done
# st # 1154 of 1185 is done
# st # 1155 of 1185 is done
# st # 1156 of 1185 is done
# st # 1157 of 1185 is done
# st # 1158 of 1185 is done
# st # 1159 of 1185 is done
# st # 1160 of 1185 is done
# st # 1161 of 1185 is done
# st # 1162 of 1185 is done
# st # 1163 of 1185 is done
# st # 1164 of 1185 is done
# st # 1165 of 1185 is done
# st # 1166 of 1185 is done
# st # 1167 of 1185 is done
# st # 1168 of 1185 is done
# st # 1169 of 1185 is done
# st # 1170 of 1185 is done
# st # 1171 of 1185 is done
# st # 1172 of 1185 is done
# st # 1173 of 1185 is done
# st # 1174 of 1185 is done
# st # 1175 of 1185 is done
# st # 1176 of 1185 is done
# st # 1177 of 1185 is done
# st # 1178 of 1185 is done
# st # 1179 of 1185 is done
# st # 1180 of 1185 is done
# st # 1181 of 1185 is done
# st # 1182 of 1185 is done
# st # 1183 of 1185 is done
# st # 1184 of 1185 is done

# %%
######## DOWNLOAD AND SAVE PROCESSED WAVEFORMS ###########
all_metadata_df = pd.read_csv((meta_dir + 'metadata_all.csv'))
#all_metadata_df = pd.read_csv((meta_dir + 'metadata_dldata.csv'))



dlsuccess = [False] * len(all_metadata_df)
for recording_i in range(len(all_metadata_df)):
    try:
        i_st = client.get_waveforms(network="*",station=all_metadata_df.stations[recording_i],location="*",
                                    channel="???",starttime=metadata_all['collecttime'][recording_i],
                                    endtime=metadata_all['endtime'][recording_i],attach_response=True)
        dlsuccess[recording_i] = True
        print(np.str(recording_i) +  ' for station ' + np.str(all_metadata_df.stations[recording_i]) + ' evm ' + np.str(all_metadata_df.mag[recording_i]) + ' downloaded waveforms')
    except:
        dlsuccess[recording_i] = False
        print(np.str(recording_i) + ' has nothing')
    ## if there's data, keep going...
    if dlsuccess[recording_i]==True:
        print('moving on...')
        # remove response - get sensitivity for accelerometer since it's a flat gain:
        for j_channel in range(len(i_st)):
            ij_sensitivity = i_st[j_channel].stats.response.instrument_sensitivity.value
            i_st[j_channel].data = i_st[j_channel].data / ij_sensitivity
        
        ## Remove pre-event baseline mean:
#         for j_channel in range(len(i_st)):
#             ij_5sec_index = np.where(i_st[j_channel].times() <= 5)[0]
#             ij_preeventmean = np.mean(i_st[j_channel].data[ij_5sec_index])
#             i_st[j_channel].data = i_st[j_channel].data - ij_preeventmean
        
        ### save the data....
        i_datetime = UTCDateTime(all_metadata_df.collecttime[recording_i]).datetime
        i_time_for_path = np.str(i_datetime.year) + np.str(i_datetime.month)+ np.str(i_datetime.day)+ np.str(i_datetime.hour)+ np.str(i_datetime.minute)+ np.str(i_datetime.second)+ np.str(i_datetime.microsecond)
        i_mseedpath = mseed_dir + np.str(all_metadata_df.stations[recording_i]) + '_' + np.str(all_metadata_df.mag[recording_i]) + '_' + np.str(np.round(all_metadata_df.distance[recording_i],decimals=2)) + '_' + i_time_for_path + '.mseed'
        i_st.write(i_mseedpath,format='mseed')

## save metadata file with only dlsuccess:
dl_metadata_df = all_metadata_df[dlsuccess]
dl_metadata_df.to_csv((meta_dir + 'metadata_dldata.csv'),index=False)
# Out:
# 0 has nothing
# 1 has nothing
# 2 has nothing
# 3 has nothing
# 4 has nothing
# 5 has nothing
# 6 has nothing
# 7 has nothing
# 8 has nothing
# 9 has nothing
# 10 has nothing
# 11 has nothing
# 12 has nothing
# 13 has nothing
# 14 has nothing
# 15 has nothing
# 16 has nothing
# 17 has nothing
# 18 has nothing
# 19 has nothing
# 20 has nothing
# 21 has nothing
# 22 has nothing
# 23 has nothing
# 24 has nothing
# 25 has nothing
# 26 has nothing
# 27 has nothing
# 28 has nothing
# 29 has nothing
# 30 has nothing
# 31 has nothing
# 32 has nothing
# 33 has nothing
# 34 has nothing
# 35 has nothing
# 36 has nothing
# 37 has nothing
# 38 has nothing
# 39 has nothing
# 40 has nothing
# 41 has nothing
# 42 has nothing
# 43 has nothing
# 44 has nothing
# 45 has nothing
# 46 has nothing
# 47 has nothing
# 48 has nothing
# 49 has nothing
# 50 has nothing
# 51 has nothing
# 52 has nothing
# 53 has nothing
# 54 has nothing
# 55 has nothing
# 56 has nothing
# 57 has nothing
# 58 has nothing
# 59 has nothing
# 60 has nothing
# 61 has nothing
# 62 has nothing
# 63 has nothing
# 64 has nothing
# 65 has nothing
# 66 has nothing
# 67 has nothing
# 68 has nothing
# 69 has nothing
# 70 has nothing
# 71 has nothing
# 72 has nothing
# 73 has nothing
# 74 has nothing
# 75 has nothing
# 76 has nothing
# 77 has nothing
# 78 has nothing
# 79 has nothing
# 80 has nothing
# 81 has nothing
# 82 has nothing
# 83 has nothing
# 84 has nothing
# 85 has nothing
# 86 has nothing
# 87 has nothing
# 88 has nothing
# 89 has nothing
# 90 has nothing
# 91 has nothing
# 92 has nothing
# 93 has nothing
# 94 has nothing
# 95 has nothing
# 96 has nothing
# 97 has nothing
# 98 has nothing
# 99 has nothing
# 100 has nothing
# 101 has nothing
# 102 has nothing
# 103 has nothing
# 104 has nothing
# 105 has nothing
# 106 has nothing
# 107 has nothing
# 108 has nothing
# 109 has nothing
# 110 has nothing
# 111 has nothing
# 112 has nothing
# 113 has nothing
# 114 has nothing
# 115 has nothing
# 116 has nothing
# 117 has nothing
# 118 has nothing
# 119 has nothing
# 120 has nothing
# 121 has nothing
# 122 has nothing
# 123 has nothing
# 124 has nothing
# 125 has nothing
# 126 has nothing
# 127 has nothing
# 128 has nothing
# 129 has nothing
# 130 has nothing
# 131 has nothing
# 132 has nothing
# 133 has nothing
# 134 has nothing
# 135 has nothing
# 136 has nothing
# 137 has nothing
# 138 has nothing
# 139 has nothing
# 140 has nothing
# 141 has nothing
# 142 has nothing
# 143 has nothing
# 144 has nothing
# 145 has nothing
# 146 has nothing
# 147 has nothing
# 148 has nothing
# 149 has nothing
# 150 has nothing
# 151 has nothing
# 152 has nothing
# 153 has nothing
# 154 has nothing
# 155 has nothing
# 156 has nothing
# 157 has nothing
# 158 has nothing
# 159 has nothing
# 160 has nothing
# 161 has nothing
# 162 has nothing
# 163 has nothing
# 164 has nothing
# 165 has nothing
# 166 has nothing
# 167 has nothing
# 168 has nothing
# 169 has nothing
# 170 has nothing
# 171 has nothing
# 172 has nothing
# 173 has nothing
# 174 has nothing
# 175 has nothing
# 176 has nothing
# 177 has nothing
# 178 has nothing
# 179 has nothing
# 180 has nothing
# 181 has nothing
# 182 has nothing
# 183 has nothing
# 184 has nothing
# 185 has nothing
# 186 has nothing
# 187 has nothing
# 188 has nothing
# 189 has nothing
# 190 has nothing
# 191 has nothing
# 192 has nothing
# 193 has nothing
# 194 has nothing
# 195 has nothing
# 196 has nothing
# 197 has nothing
# 198 has nothing
# 199 has nothing
# 200 has nothing
# 201 has nothing
# 202 has nothing
# 203 has nothing
# 204 has nothing
# 205 has nothing
# 206 has nothing
# 207 has nothing
# 208 has nothing
# 209 has nothing
# 210 has nothing
# 211 has nothing
# 212 has nothing
# 213 has nothing
# 214 has nothing
# 215 has nothing
# 216 has nothing
# 217 has nothing
# 218 has nothing
# 219 has nothing
# 220 has nothing
# 221 has nothing
# 222 has nothing
# 223 has nothing
# 224 has nothing
# 225 has nothing
# 226 has nothing
# 227 has nothing
# 228 has nothing
# 229 has nothing
# 230 has nothing
# 231 has nothing
# 232 has nothing
# 233 has nothing
# 234 has nothing
# 235 has nothing
# 236 has nothing
# 237 has nothing
# 238 has nothing
# 239 has nothing
# 240 has nothing
# 241 has nothing
# 242 has nothing
# 243 has nothing
# 244 has nothing
# 245 has nothing
# 246 has nothing
# 247 has nothing
# 248 has nothing
# 249 has nothing
# 250 has nothing
# 251 has nothing
# 252 has nothing
# 253 has nothing
# 254 has nothing
# 255 has nothing
# 256 has nothing
# 257 has nothing
# 258 has nothing
# 259 has nothing
# 260 has nothing
# 261 has nothing
# 262 has nothing
# 263 has nothing
# 264 has nothing
# 265 has nothing
# 266 has nothing
# 267 has nothing
# 268 has nothing
# 269 has nothing
# 270 has nothing
# 271 has nothing
# 272 has nothing
# 273 has nothing
# 274 has nothing
# 275 has nothing
# 276 has nothing
# 277 has nothing
# 278 has nothing
# 279 has nothing
# 280 has nothing
# 281 has nothing
# 282 has nothing
# 283 has nothing
# 284 has nothing
# 285 has nothing
# 286 has nothing
# 287 has nothing
# 288 has nothing
# 289 has nothing
# 290 has nothing
# 291 has nothing
# 292 has nothing
# 293 has nothing
# 294 has nothing
# 295 has nothing
# 296 has nothing
# 297 has nothing
# 298 has nothing
# 299 has nothing
# 300 has nothing
# 301 has nothing
# 302 has nothing
# 303 has nothing
# 304 has nothing
# 305 has nothing
# 306 has nothing
# 307 has nothing
# 308 has nothing
# 309 has nothing
# 310 has nothing
# 311 has nothing
# 312 has nothing
# 313 has nothing
# 314 has nothing
# 315 has nothing
# 316 has nothing
# 317 has nothing
# 318 has nothing
# 319 has nothing
# 320 has nothing
# 321 has nothing
# 322 has nothing
# 323 has nothing
# 324 has nothing
# 325 has nothing
# 326 has nothing
# 327 has nothing
# 328 has nothing
# 329 has nothing
# 330 has nothing
# 331 has nothing
# 332 has nothing
# 333 has nothing
# 334 has nothing
# 335 has nothing
# 336 has nothing
# 337 has nothing
# 338 has nothing
# 339 has nothing
# 340 has nothing
# 341 has nothing
# 342 has nothing
# 343 has nothing
# 344 has nothing
# 345 has nothing
# 346 has nothing
# 347 has nothing
# 348 has nothing
# 349 has nothing
# 350 has nothing
# 351 has nothing
# 352 has nothing
# 353 has nothing
# 354 has nothing
# 355 has nothing
# 356 has nothing
# 357 has nothing
# 358 has nothing
# 359 has nothing
# 360 has nothing
# 361 has nothing
# 362 has nothing
# 363 has nothing
# 364 has nothing
# 365 has nothing
# 366 has nothing
# 367 has nothing
# 368 has nothing
# 369 has nothing
# 370 has nothing
# 371 has nothing
# 372 has nothing
# 373 has nothing
# 374 has nothing
# 375 has nothing
# 376 has nothing
# 377 has nothing
# 378 has nothing
# 379 has nothing
# 380 has nothing
# 381 has nothing
# 382 has nothing
# 383 has nothing
# 384 has nothing
# 385 has nothing
# 386 has nothing
# 387 has nothing
# 388 has nothing
# 389 has nothing
# 390 has nothing
# 391 has nothing
# 392 has nothing
# 393 has nothing
# 394 has nothing
# 395 has nothing
# 396 has nothing
# 397 has nothing
# 398 has nothing
# 399 has nothing
# 400 has nothing
# 401 has nothing
# 402 has nothing
# 403 has nothing
# 404 has nothing
# 405 has nothing
# 406 has nothing
# 407 has nothing
# 408 has nothing
# 409 has nothing
# 410 has nothing
# 411 has nothing
# 412 has nothing
# 413 has nothing
# 414 has nothing
# 415 has nothing
# 416 has nothing
# 417 has nothing
# 418 has nothing
# 419 has nothing
# 420 has nothing
# 421 has nothing
# 422 has nothing
# 423 has nothing
# 424 has nothing
# 425 has nothing
# 426 has nothing
# 427 has nothing
# 428 has nothing
# 429 has nothing
# 430 has nothing
# 431 has nothing
# 432 has nothing
# 433 has nothing
# 434 has nothing
# 435 has nothing
# 436 has nothing
# 437 has nothing
# 438 has nothing
# 439 has nothing
# 440 has nothing
# 441 has nothing
# 442 has nothing
# 443 has nothing
# 444 has nothing
# 445 has nothing
# 446 has nothing
# 447 has nothing
# 448 has nothing
# 449 has nothing
# 450 has nothing
# 451 has nothing
# 452 has nothing
# 453 has nothing
# 454 has nothing
# 455 has nothing
# 456 has nothing
# 457 has nothing
# 458 has nothing
# 459 has nothing
# 460 has nothing
# 461 has nothing
# 462 has nothing
# 463 has nothing
# 464 has nothing
# 465 has nothing
# 466 has nothing
# 467 has nothing
# 468 has nothing
# 469 has nothing
# 470 has nothing
# 471 has nothing
# 472 has nothing
# 473 has nothing
# 474 has nothing
# 475 has nothing
# 476 has nothing
# 477 has nothing
# 478 has nothing
# 479 has nothing
# 480 has nothing
# 481 has nothing
# 482 has nothing
# 483 has nothing
# 484 has nothing
# 485 has nothing
# 486 has nothing
# 487 has nothing
# 488 has nothing
# 489 has nothing
# 490 has nothing
# 491 has nothing
# 492 has nothing
# 493 has nothing
# 494 has nothing
# 495 has nothing
# 496 has nothing
# 497 has nothing
# 498 has nothing
# 499 has nothing
# 500 has nothing
# 501 has nothing
# 502 has nothing
# 503 has nothing
# 504 has nothing
# 505 has nothing
# 506 has nothing
# 507 has nothing
# 508 has nothing
# 509 has nothing
# 510 has nothing
# 511 has nothing
# 512 has nothing
# 513 has nothing
# 514 has nothing
# 515 has nothing
# 516 has nothing
# 517 has nothing
# 518 has nothing
# 519 has nothing
# 520 has nothing
# 521 has nothing
# 522 has nothing
# 523 has nothing
# 524 has nothing
# 525 has nothing
# 526 has nothing
# 527 has nothing
# 528 has nothing
# 529 has nothing
# 530 has nothing
# 531 has nothing
# 532 has nothing
# 533 has nothing
# 534 has nothing
# 535 has nothing
# 536 has nothing
# 537 has nothing
# 538 has nothing
# 539 has nothing
# 540 has nothing
# 541 has nothing
# 542 has nothing
# 543 has nothing
# 544 has nothing
# 545 has nothing
# 546 has nothing
# 547 has nothing
# 548 has nothing
# 549 has nothing
# 550 has nothing
# 551 has nothing
# 552 has nothing
# 553 has nothing
# 554 has nothing
# 555 has nothing
# 556 has nothing
# 557 has nothing
# 558 has nothing
# 559 has nothing
# 560 has nothing
# 561 has nothing
# 562 has nothing
# 563 has nothing
# 564 has nothing
# 565 has nothing
# 566 has nothing
# 567 has nothing
# 568 has nothing
# 569 has nothing
# 570 has nothing
# 571 has nothing
# 572 has nothing
# 573 has nothing
# 574 has nothing
# 575 has nothing
# 576 has nothing
# 577 has nothing
# 578 has nothing
# 579 has nothing
# 580 has nothing
# 581 has nothing
# 582 has nothing
# 583 has nothing
# 584 has nothing
# 585 has nothing
# 586 has nothing
# 587 has nothing
# 588 has nothing
# 589 has nothing
# 590 has nothing
# 591 has nothing
# 592 has nothing
# 593 has nothing
# 594 has nothing
# 595 has nothing
# 596 has nothing
# 597 has nothing
# 598 has nothing
# 599 has nothing
# 600 has nothing
# 601 has nothing
# 602 has nothing
# 603 has nothing
# 604 has nothing
# 605 has nothing
# 606 has nothing
# 607 has nothing
# 608 has nothing
# 609 has nothing
# 610 has nothing
# 611 has nothing
# 612 has nothing
# 613 has nothing
# 614 has nothing
# 615 has nothing
# 616 has nothing
# 617 has nothing
# 618 has nothing
# 619 has nothing
# 620 has nothing
# 621 has nothing
# 622 has nothing
# 623 has nothing
# 624 has nothing
# 625 has nothing
# 626 has nothing
# 627 has nothing
# 628 has nothing
# 629 has nothing
# 630 has nothing
# 631 has nothing
# 632 has nothing
# 633 has nothing
# 634 has nothing
# 635 has nothing
# 636 has nothing
# 637 has nothing
# 638 has nothing
# 639 has nothing
# 640 has nothing
# 641 has nothing
# 642 has nothing
# 643 has nothing
# 644 has nothing
# 645 has nothing
# 646 has nothing
# 647 has nothing
# 648 has nothing
# 649 has nothing
# 650 has nothing
# 651 has nothing
# 652 has nothing
# 653 has nothing
# 654 has nothing
# 655 has nothing
# 656 has nothing
# 657 has nothing
# 658 has nothing
# 659 has nothing
# 660 has nothing
# 661 has nothing
# 662 has nothing
# 663 has nothing
# 664 has nothing
# 665 has nothing
# 666 has nothing
# 667 has nothing
# 668 has nothing
# 669 has nothing
# 670 has nothing
# 671 has nothing
# 672 has nothing
# 673 has nothing
# 674 has nothing
# 675 has nothing
# 676 has nothing
# 677 has nothing
# 678 has nothing
# 679 has nothing
# 680 has nothing
# 681 has nothing
# 682 has nothing
# 683 has nothing
# 684 has nothing
# 685 has nothing
# 686 has nothing
# 687 has nothing
# 688 has nothing
# 689 has nothing
# 690 has nothing
# 691 has nothing
# 692 has nothing
# 693 has nothing
# 694 has nothing
# 695 has nothing
# 696 has nothing
# 697 has nothing
# 698 has nothing
# 699 has nothing
# 700 has nothing
# 701 has nothing
# 702 has nothing
# 703 has nothing
# 704 has nothing
# 705 has nothing
# 706 has nothing
# 707 has nothing
# 708 has nothing
# 709 has nothing
# 710 has nothing
# 711 has nothing
# 712 has nothing
# 713 has nothing
# 714 has nothing
# 715 has nothing
# 716 has nothing
# 717 has nothing
# 718 has nothing
# 719 has nothing
# 720 has nothing
# 721 has nothing
# 722 has nothing
# 723 has nothing
# 724 has nothing
# 725 has nothing
# 726 has nothing
# 727 has nothing
# 728 has nothing
# 729 has nothing
# 730 has nothing
# 731 has nothing
# 732 has nothing
# 733 has nothing
# 734 has nothing
# 735 has nothing
# 736 has nothing
# 737 has nothing
# 738 has nothing
# 739 has nothing
# 740 has nothing
# 741 has nothing
# 742 has nothing
# 743 has nothing
# 744 has nothing
# 745 has nothing
# 746 has nothing
# 747 has nothing
# 748 has nothing
# 749 has nothing
# 750 has nothing
# 751 has nothing
# 752 has nothing
# 753 has nothing
# 754 has nothing
# 755 has nothing
# 756 has nothing
# 757 has nothing
# 758 has nothing
# 759 has nothing
# 760 has nothing
# 761 has nothing
# 762 has nothing
# 763 has nothing
# 764 has nothing
# 765 has nothing
# 766 has nothing
# 767 has nothing
# 768 has nothing
# 769 has nothing
# 770 has nothing
# 771 has nothing
# 772 has nothing
# 773 has nothing
# 774 has nothing
# 775 has nothing
# 776 has nothing
# 777 has nothing
# 778 has nothing
# 779 has nothing
# 780 has nothing
# 781 has nothing
# 782 has nothing
# 783 has nothing
# 784 has nothing
# 785 has nothing
# 786 has nothing
# 787 has nothing
# 788 has nothing
# 789 has nothing
# 790 has nothing
# 791 has nothing
# 792 has nothing
# 793 has nothing
# 794 has nothing
# 795 has nothing
# 796 has nothing
# 797 has nothing
# 798 has nothing
# 799 has nothing
# 800 has nothing
# 801 has nothing
# 802 has nothing
# 803 has nothing
# 804 has nothing
# 805 has nothing
# 806 has nothing
# 807 has nothing
# 808 has nothing
# 809 has nothing
# 810 has nothing
# 811 has nothing
# 812 has nothing
# 813 has nothing
# 814 has nothing
# 815 has nothing
# 816 has nothing
# 817 has nothing
# 818 has nothing
# 819 has nothing
# 820 has nothing
# 821 has nothing
# 822 has nothing
# 823 has nothing
# 824 has nothing
# 825 has nothing
# 826 has nothing
# 827 has nothing
# 828 has nothing
# 829 has nothing
# 830 has nothing
# 831 has nothing
# 832 has nothing
# 833 has nothing
# 834 has nothing
# 835 has nothing
# 836 has nothing
# 837 has nothing
# 838 has nothing
# 839 has nothing
# 840 has nothing
# 841 has nothing
# 842 has nothing
# 843 has nothing
# 844 has nothing
# 845 has nothing
# 846 has nothing
# 847 has nothing
# 848 has nothing
# 849 has nothing
# 850 has nothing
# 851 has nothing
# 852 has nothing
# 853 has nothing
# 854 has nothing
# 855 has nothing
# 856 has nothing
# 857 has nothing
# 858 has nothing
# 859 has nothing
# 860 has nothing
# 861 has nothing
# 862 has nothing
# 863 has nothing
# 864 has nothing
# 865 has nothing
# 866 has nothing
# 867 has nothing
# 868 has nothing
# 869 has nothing
# 870 has nothing
# 871 has nothing
# 872 has nothing
# 873 has nothing
# 874 has nothing
# 875 has nothing
# 876 has nothing
# 877 has nothing
# 878 has nothing
# 879 has nothing
# 880 has nothing
# 881 has nothing
# 882 has nothing
# 883 has nothing
# 884 has nothing
# 885 has nothing
# 886 has nothing
# 887 has nothing
# 888 has nothing
# 889 has nothing
# 890 has nothing
# 891 has nothing
# 892 has nothing
# 893 has nothing
# 894 has nothing
# 895 has nothing
# 896 has nothing
# 897 has nothing
# 898 has nothing
# 899 has nothing
# 900 has nothing
# 901 has nothing
# 902 has nothing
# 903 has nothing
# 904 has nothing
# 905 has nothing
# 906 has nothing
# 907 has nothing
# 908 has nothing
# 909 has nothing
# 910 has nothing
# 911 has nothing
# 912 has nothing
# 913 has nothing
# 914 has nothing
# 915 has nothing
# 916 has nothing
# 917 has nothing
# 918 has nothing
# 919 has nothing
# 920 has nothing
# 921 has nothing
# 922 has nothing
# 923 has nothing
# 924 has nothing
# 925 has nothing
# 926 has nothing
# 927 has nothing
# 928 has nothing
# 929 has nothing
# 930 has nothing
# 931 has nothing
# 932 has nothing
# 933 has nothing
# 934 has nothing
# 935 has nothing
# 936 has nothing
# 937 has nothing
# 938 has nothing
# 939 has nothing
# 940 has nothing
# 941 has nothing
# 942 has nothing
# 943 has nothing
# 944 has nothing
# 945 has nothing
# 946 has nothing
# 947 has nothing
# 948 has nothing
# 949 has nothing
# 950 has nothing
# 951 has nothing
# 952 has nothing
# 953 has nothing
# 954 has nothing
# 955 has nothing
# 956 has nothing
# 957 has nothing
# 958 has nothing
# 959 has nothing
# 960 has nothing
# 961 has nothing
# 962 has nothing
# 963 has nothing
# 964 has nothing
# 965 has nothing
# 966 has nothing
# 967 has nothing
# 968 has nothing
# 969 has nothing
# 970 has nothing
# 971 has nothing
# 972 has nothing
# 973 has nothing
# 974 has nothing
# 975 has nothing
# 976 has nothing
# 977 has nothing
# 978 has nothing
# 979 has nothing
# 980 has nothing
# 981 has nothing
# 982 has nothing
# 983 has nothing
# 984 has nothing
# 985 has nothing
# 986 has nothing
# 987 has nothing
# 988 has nothing
# 989 has nothing
# 990 has nothing
# 991 has nothing
# 992 has nothing
# 993 has nothing
# 994 has nothing
# 995 has nothing
# 996 has nothing
# 997 has nothing
# 998 has nothing
# 999 has nothing
# 1000 has nothing
# 1001 has nothing
# 1002 has nothing
# 1003 has nothing
# 1004 has nothing
# 1005 has nothing
# 1006 has nothing
# 1007 has nothing
# 1008 has nothing
# 1009 has nothing
# 1010 has nothing
# 1011 has nothing
# 1012 has nothing
# 1013 has nothing
# 1014 has nothing
# 1015 has nothing
# 1016 has nothing
# 1017 has nothing
# 1018 has nothing
# 1019 has nothing
# 1020 has nothing
# 1021 has nothing
# 1022 has nothing
# 1023 has nothing
# 1024 has nothing
# 1025 has nothing
# 1026 has nothing
# 1027 has nothing
# 1028 has nothing
# 1029 has nothing
# 1030 has nothing
# 1031 has nothing
# 1032 has nothing
# 1033 has nothing
# 1034 has nothing
# 1035 has nothing
# 1036 has nothing
# 1037 has nothing
# 1038 has nothing
# 1039 has nothing
# 1040 has nothing
# 1041 has nothing
# 1042 has nothing
# 1043 has nothing
# 1044 has nothing
# 1045 has nothing
# 1046 has nothing
# 1047 has nothing
# 1048 has nothing
# 1049 has nothing
# 1050 has nothing
# 1051 has nothing
# 1052 has nothing
# 1053 has nothing
# 1054 has nothing
# 1055 has nothing
# 1056 has nothing
# 1057 has nothing
# 1058 has nothing
# 1059 has nothing
# 1060 has nothing
# 1061 has nothing
# 1062 has nothing
# 1063 has nothing
# 1064 has nothing
# 1065 has nothing
# 1066 has nothing
# 1067 has nothing
# 1068 has nothing
# 1069 has nothing
# 1070 has nothing
# 1071 has nothing
# 1072 has nothing
# 1073 has nothing
# 1074 has nothing
# 1075 has nothing
# 1076 has nothing
# 1077 has nothing
# 1078 has nothing
# 1079 has nothing
# 1080 has nothing
# 1081 has nothing
# 1082 has nothing
# 1083 has nothing
# 1084 has nothing
# 1085 has nothing
# 1086 has nothing
# 1087 has nothing
# 1088 has nothing
# 1089 has nothing
# 1090 has nothing
# 1091 has nothing
# 1092 has nothing
# 1093 has nothing
# 1094 has nothing
# 1095 has nothing
# 1096 has nothing
# 1097 has nothing
# 1098 has nothing
# 1099 has nothing
# 1100 has nothing
# 1101 has nothing
# 1102 has nothing
# 1103 has nothing
# 1104 has nothing
# 1105 has nothing
# 1106 has nothing
# 1107 has nothing
# 1108 has nothing
# 1109 has nothing
# 1110 has nothing
# 1111 has nothing
# 1112 has nothing
# 1113 has nothing
# 1114 has nothing
# 1115 has nothing
# 1116 has nothing
# 1117 has nothing
# 1118 has nothing
# 1119 has nothing
# 1120 has nothing
# 1121 has nothing
# 1122 has nothing
# 1123 has nothing
# 1124 has nothing
# 1125 has nothing
# 1126 has nothing
# 1127 has nothing
# 1128 has nothing
# 1129 has nothing
# 1130 has nothing
# 1131 has nothing
# 1132 has nothing
# 1133 has nothing
# 1134 has nothing
# 1135 has nothing
# 1136 has nothing
# 1137 has nothing
# 1138 has nothing
# 1139 has nothing
# 1140 has nothing
# 1141 has nothing
# 1142 has nothing
# 1143 has nothing
# 1144 has nothing
# 1145 has nothing
# 1146 has nothing
# 1147 has nothing
# 1148 has nothing
# 1149 has nothing
# 1150 has nothing
# 1151 has nothing
# 1152 has nothing
# 1153 has nothing
# 1154 has nothing
# 1155 has nothing
# 1156 has nothing
# 1157 has nothing
# 1158 has nothing
# 1159 has nothing
# 1160 has nothing
# 1161 has nothing
# 1162 has nothing
# 1163 has nothing
# 1164 has nothing
# 1165 has nothing
# 1166 has nothing
# 1167 has nothing
# 1168 has nothing
# 1169 has nothing
# 1170 has nothing
# 1171 has nothing
# 1172 has nothing
# 1173 has nothing
# 1174 has nothing
# 1175 has nothing
# 1176 has nothing
# 1177 has nothing
# 1178 has nothing
# 1179 has nothing
# 1180 has nothing
# 1181 has nothing
# 1182 has nothing
# 1183 has nothing
# 1184 has nothing
# /var/folders/b9/lpn_b8pj1n7_m6yczj34v_080000gn/T/ipykernel_46492/2053336032.py:17: DeprecationWarning: `np.str` is a deprecated alias for the builtin `str`. To silence this warning, use `str` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.str_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   print(np.str(recording_i) + ' has nothing')

# %%
main_flatfile_path = '/Users/rshimony/Desktop/WillametteValley/eve_4_inv/metadata/full_flatfile.csv'

allmetadata = pd.read_csv(main_flatfile_path)

# %%
i_origintime = allmetadata['OrgT']
# i_date,i_time = allmetadata['OrgT'].split(' ')
# i_year,i_month,i_day = i_date.split('-')
# i_hr,i_min,i_sec = i_time.split(':')

# %%
i_date,i_time = i_origintime[3].split(' ')
print(i_date)
print(i_time)

i_year,i_month,i_day = i_date.split('-')
print(i_year)
print(i_month)
print(i_day)
# Out:
# 2020-12-04
# 14:07:31
# 2020
# 12
# 04
