# %%
import numpy as np
import matplotlib.pyplot as plt
import pySW4 as sw4
import pandas as pd
import obspy as obs
from glob import glob
# %matplotlib inline
# Out:
# /opt/anaconda3/envs/branch-env/lib/python3.8/site-packages/pySW4/utils/utils.py:28: UserWarning: OpenCV not found, you will not be able to use `pySW4.utils.resample` in `draft` mode.
#   warn('OpenCV not found, you will not be able to use '

# %%
img1n_1=sw4.read_image('/Users/rshimony/Desktop/WillametteValley/mini_model/results_1/image.cycle=0000.z=0.s.sw4img')
img2n_1=sw4.read_image('/Users/rshimony/Desktop/WillametteValley/mini_model/results_1/image.cycle=0000.x=10000.s.sw4img')
img3n_1=sw4.read_image('/Users/rshimony/Desktop/WillametteValley/mini_model/results_1/image.cycle=0000.x=58000.s.sw4img')
img4n_1=sw4.read_image('/Users/rshimony/Desktop/WillametteValley/mini_model/results_1/image.cycle=0000.x=85000.s.sw4img')
img5n_1=sw4.read_image('/Users/rshimony/Desktop/WillametteValley/mini_model/results_1/image.cycle=0000.x=105000.s.sw4img')
img6n_1=sw4.read_image('/Users/rshimony/Desktop/WillametteValley/mini_model/results_1/image.cycle=0000.x=110000.s.sw4img')
img7n_1=sw4.read_image('/Users/rshimony/Desktop/WillametteValley/mini_model/results_1/image.cycle=0000.x=120000.s.sw4img')
img8n_1=sw4.read_image('/Users/rshimony/Desktop/WillametteValley/mini_model/results_1/image.cycle=0000.x=130000.s.sw4img')
img9n_1=sw4.read_image('/Users/rshimony/Desktop/WillametteValley/mini_model/results_1/image.cycle=0000.y=42500.s.sw4img')
img10n_1=sw4.read_image('/Users/rshimony/Desktop/WillametteValley/mini_model/results_1/image.cycle=0000.y=10000.s.sw4img')
img11n_1=sw4.read_image('/Users/rshimony/Desktop/WillametteValley/mini_model/results_1/image.cycle=0000.y=75000.s.sw4img')

# %%
fig1,ax1,cb1=img1n_1.plot()
fig1.set_size_inches(10,10)
fig2,ax2,cb2=img2n_1.plot()
fig2.set_size_inches(20,20)
fig3,ax3,cb3=img3n_1.plot()
fig3.set_size_inches(20,20)
fig4,ax4,cb4=img4n_1.plot()
fig4.set_size_inches(20,20)
fig5,ax5,cb5=img5n_1.plot()
fig5.set_size_inches(20,20)
fig6,ax6,cb6=img6n_1.plot()
fig6.set_size_inches(20,20)
fig7,ax7,cb7=img7n_1.plot()
fig7.set_size_inches(20,20)
fig8,ax8,cb8=img8n_1.plot()
fig8.set_size_inches(20,20)
fig9,ax9,cb9=img9n_1.plot()
fig9.set_size_inches(20,20)
fig10,ax10,cb10=img10n_1.plot()
fig10.set_size_inches(20,20)
fig11,ax11,cb11=img11n_1.plot()
fig11.set_size_inches(20,20)
plt.show()

# %%
img1n=sw4.read_image('/Users/rshimony/Desktop/WillametteValley/mini_model/results/image.cycle=0000.z=0.s.sw4img')
img2n=sw4.read_image('/Users/rshimony/Desktop/WillametteValley/mini_model/results/image.cycle=0000.x=10000.s.sw4img')
img3n=sw4.read_image('/Users/rshimony/Desktop/WillametteValley/mini_model/results/image.cycle=0000.x=58000.s.sw4img')
img4n=sw4.read_image('/Users/rshimony/Desktop/WillametteValley/mini_model/results/image.cycle=0000.x=85000.s.sw4img')
img5n=sw4.read_image('/Users/rshimony/Desktop/WillametteValley/mini_model/results/image.cycle=0000.x=105000.s.sw4img')
img6n=sw4.read_image('/Users/rshimony/Desktop/WillametteValley/mini_model/results/image.cycle=0000.x=110000.s.sw4img')
img7n=sw4.read_image('/Users/rshimony/Desktop/WillametteValley/mini_model/results/image.cycle=0000.x=120000.s.sw4img')
img8n=sw4.read_image('/Users/rshimony/Desktop/WillametteValley/mini_model/results/image.cycle=0000.x=130000.s.sw4img')
img9n=sw4.read_image('/Users/rshimony/Desktop/WillametteValley/mini_model/results/image.cycle=0000.y=42500.s.sw4img')
img10n=sw4.read_image('/Users/rshimony/Desktop/WillametteValley/mini_model/results/image.cycle=0000.y=10000.s.sw4img')
img11n=sw4.read_image('/Users/rshimony/Desktop/WillametteValley/mini_model/results/image.cycle=0000.y=75000.s.sw4img')

# %%
fig1,ax1,cb1=img1n.plot()
fig1.set_size_inches(20,10)
plt.savefig('/Users/rshimony/Desktop/WillametteValley/mini_model/mini_z=0.jpg',dpi=300,bbox_inches='tight')

fig2,ax2,cb2=img2n.plot()
fig2.set_size_inches(20,20)

fig3,ax3,cb3=img3n.plot()
fig3.set_size_inches(20,20)

fig4,ax4,cb4=img4n.plot()
fig4.set_size_inches(20,20)

fig5,ax5,cb5=img5n.plot()
fig5.set_size_inches(20,20)
plt.savefig('/Users/rshimony/Desktop/WillametteValley/mini_model/mini_x=105.jpg',dpi=300,bbox_inches='tight')

fig6,ax6,cb6=img6n.plot()
fig6.set_size_inches(20,20)

fig7,ax7,cb7=img7n.plot()
fig7.set_size_inches(20,20)

fig8,ax8,cb8=img8n.plot()
fig8.set_size_inches(20,20)
plt.savefig('/Users/rshimony/Desktop/WillametteValley/mini_model/mini_x=130.jpg',dpi=300,bbox_inches='tight')

fig9,ax9,cb9=img9n.plot(cmap='terrain')
fig9.set_size_inches(30,20)
plt.savefig('/Users/rshimony/Desktop/WillametteValley/mini_model/mini_y=42.jpg',dpi=300,bbox_inches='tight')

fig10,ax10,cb10=img10n.plot()
fig10.set_size_inches(20,20)

fig11,ax11,cb11=img11n.plot()
fig11.set_size_inches(20,20)

plt.show()

# %%
wells = pd.read_csv('/Users/rshimony/Desktop/WillametteValley/Model_stru/Map_Wells_spine.csv')
wells_name = wells['SiteName']
wells_depth = wells['Depth[m]']
wells_x = wells['x_init'][:4]
wells_z = np.zeros_like(wells_x)

filename='/Users/rshimony/Desktop/WillametteValley/Init_Model/init_model_topcon/results/image.cycle=00000.y=42500.s.sw4img'
image=sw4.read_image(filename)
model=image.patches[0].data
fig,ax=plt.subplots(ncols=1,nrows=1,figsize=(24,5))
km=1./1000
extent=([0,135000,10000,0])
ax.tick_params(axis='both', which='major', labelsize=23)
ax.set_ylabel('Z (m)',fontsize=25)
ax.set_xlabel('N-S (m)',fontsize=25)
# im=ax1.imshow(model,extent=extent,cmap='terrain',vmax=3000)
im=ax.imshow(model,extent=extent,cmap='terrain')
ax.xaxis.set_ticks(np.arange(0, 135000, 10000))

from matplotlib.ticker import MultipleLocator
xspacing = 1000 # This can be your user specified spacing. 
xminorLocator = MultipleLocator(xspacing)
ax.xaxis.set_minor_locator(xminorLocator)
yspacing = 1000 # This can be your user specified spacing. 
yminorLocator = MultipleLocator(yspacing)
ax.xaxis.set_minor_locator(xminorLocator)
ax.yaxis.set_minor_locator(yminorLocator)

ax.scatter(wells_x,wells_z, clip_on=False , marker='o' , c='lightgrey' , edgecolors='k',s=400)

for i in range(len(wells_z)):
    ax.plot([wells_x[i],wells_x[i]] , [wells_z[i],wells_depth[i]] , color='k',lw=2.5)
    ax.text(wells_x[i]-3000,-600,wells_name[i], color='k',size=22)

# ax.grid()


# CBx=np.asarray([0,31500,60000,83000,83000,83000,93000,93000,120000]) #Cryst
# CBy=np.asarray([4000,7500,14000,14000,14000,7000,7000,14000,14000])
# MSx=np.asarray([0,35000,60000,83000,120000])
# MSy=np.asarray([1000,4600,7000,7000,7000])
# KSx=np.asarray([83000,83000,93000,93000])
# KSy=np.asarray([7000,600,600,7000])

# ax.plot(CBx,CBy,'r')
# ax.plot(MSx,MSy,'r',linestyle='-.')
# ax.plot(KSx,KSy,'r',linestyle='-.')
# # ax.plot(x1,y1,'r')

# ax.text(40000,15000,'Crystaline Basment',size=14,rotation=-12)
# ax.text(60000,11000,'pre-M.S',size=14)
# ax.text(100000,11000,'pre-M.S',size=14)
# #ax.text(86000,4000,'MS',size=14)
# ax.text(60000,4000,'post-M.S',size=14)
# ax.text(100000,4000,'post-M.S',size=14)
# ax.text(87000,-500,'KS',size=14)
# ax.text(105000,-500,'Hula Valley',size=14)
# ax.text(40000,-500,'Jordan Valley',size=14)
# ax.text(0,-500,'A',size=16)
# ax.text(120000,-500,"A'",size=16)

ax.set_ylim(10000,0)
ax.set_xlim(0,135000)

ax.set_aspect('auto')

# ax.tick_params(axis='both', which='major', labelsize=14)
#ax.tick_params(axis='both', which='minor', labelsize=8)
from mpl_toolkits.axes_grid1.inset_locator import inset_axes

axins1 = inset_axes(ax, width="20.%",height='5%',loc='lower left',bbox_to_anchor=(0.01, 0.12, 1, 1),
                   bbox_transform=ax.transAxes,
                   borderpad=2)
cb=fig.colorbar(im, cax=axins1, orientation="horizontal")
cb.ax.tick_params(labelsize=15) 
cb.set_label('Vs [m/sec]',size=15)

ax.plot([0,135000],[5000,5000],'r',linestyle='-.')

ax.text(-100,-300,'A',weight='bold' , color='crimson',size=25)
ax.text(135150,-300,"A'",weight='bold' , color='crimson',size=25)

fig.savefig('/Users/rshimony/Documents/agu_poster/figs/mini_y=42_t.jpg',dpi=300,bbox_inches='tight',transparent=True)

# %%
filename='/Users/rshimony/Desktop/WillametteValley/Init_Model/init_model_topcon/results/image.cycle=00000.x=130000.s.sw4img'
image=sw4.read_image(filename)
model=image.patches[0].data
fig,ax=plt.subplots(ncols=1,nrows=1,figsize=(24,5))
km=1./1000
extent=([0,85000,10000,0])
ax.tick_params(axis='both', which='major', labelsize=23)
ax.set_ylabel('Z (m)',fontsize=25)
ax.set_xlabel('E-W (m)',fontsize=25)
# im=ax1.imshow(model,extent=extent,cmap='terrain',vmax=3000)
im=ax.imshow(model,extent=extent,cmap='terrain')
ax.xaxis.set_ticks(np.arange(0, 85000, 10000))

from matplotlib.ticker import MultipleLocator
xspacing = 1000 # This can be your user specified spacing. 
xminorLocator = MultipleLocator(xspacing)
ax.xaxis.set_minor_locator(xminorLocator)
yspacing = 1000 # This can be your user specified spacing. 
yminorLocator = MultipleLocator(yspacing)
ax.xaxis.set_minor_locator(xminorLocator)
ax.yaxis.set_minor_locator(yminorLocator)

# ax.grid()


# CBx=np.asarray([0,31500,60000,83000,83000,83000,93000,93000,120000]) #Cryst
# CBy=np.asarray([4000,7500,14000,14000,14000,7000,7000,14000,14000])
# MSx=np.asarray([0,35000,60000,83000,120000])
# MSy=np.asarray([1000,4600,7000,7000,7000])
# KSx=np.asarray([83000,83000,93000,93000])
# KSy=np.asarray([7000,600,600,7000])

# ax.plot(CBx,CBy,'r')
# ax.plot(MSx,MSy,'r',linestyle='-.')
# ax.plot(KSx,KSy,'r',linestyle='-.')
# # ax.plot(x1,y1,'r')

# ax.text(40000,15000,'Crystaline Basment',size=14,rotation=-12)
# ax.text(60000,11000,'pre-M.S',size=14)
# ax.text(100000,11000,'pre-M.S',size=14)
# #ax.text(86000,4000,'MS',size=14)
# ax.text(60000,4000,'post-M.S',size=14)
# ax.text(100000,4000,'post-M.S',size=14)
# ax.text(87000,-500,'KS',size=14)
# ax.text(105000,-500,'Hula Valley',size=14)
# ax.text(40000,-500,'Jordan Valley',size=14)
# ax.text(0,-500,'A',size=16)
# ax.text(120000,-500,"A'",size=16)

ax.set_ylim(10000,0)
ax.set_xlim(0,85000)

ax.set_aspect('auto')

# ax.tick_params(axis='both', which='major', labelsize=14)
#ax.tick_params(axis='both', which='minor', labelsize=8)
from mpl_toolkits.axes_grid1.inset_locator import inset_axes

axins1 = inset_axes(ax, width="20.%",height='5%',loc='lower left',bbox_to_anchor=(0.01, 0.15, 1, 1),
                   bbox_transform=ax.transAxes, borderpad=2)
cb=fig.colorbar(im, cax=axins1, orientation="horizontal")
cb.set_label('Vs [m/sec]',size=15)
cb.ax.tick_params(labelsize=15) 

ax.plot([0,85000],[5000,5000],'r',linestyle='-.')

ax.text(-100,-300,'B',weight='bold' , color='crimson',size=25)
ax.text(85150,-300,"B'",weight='bold' , color='crimson',size=25)

fig.savefig('/Users/rshimony/Documents/agu_poster/figs/mini_x=130_t.jpg',dpi=300,bbox_inches='tight',transparent=True)

# %%
img1n_1=sw4.read_image("/Users/rshimony/Desktop/WillametteValley/Models/no_refinement_figs/rfile_steph_basin_salem_cart_eugspe_sm/image.cycle=0000.z=0.s.sw4img")
img2n_1=sw4.read_image("/Users/rshimony/Desktop/WillametteValley/Models/no_refinement_figs/rfile_steph_basin_salem_cart_eugspe_sm/image.cycle=0000.y=80000.s.sw4img")
img3n_1=sw4.read_image("/Users/rshimony/Desktop/WillametteValley/Models/no_refinement_figs/rfile_steph_basin_salem_cart_eugspe_sm/image.cycle=0000.y=90000.s.sw4img")
img4n_1=sw4.read_image("/Users/rshimony/Desktop/WillametteValley/Models/no_refinement_figs/rfile_steph_basin_salem_cart_eugspe_sm/image.cycle=0000.y=100000.s.sw4img")
img5n_1=sw4.read_image("/Users/rshimony/Desktop/WillametteValley/Models/no_refinement_figs/rfile_steph_basin_salem_cart_eugspe_sm/image.cycle=0000.y=110000.s.sw4img")
img6n_1=sw4.read_image("/Users/rshimony/Desktop/WillametteValley/Models/no_refinement_figs/rfile_steph_basin_salem_cart_eugspe_sm/image.cycle=0000.y=120000.s.sw4img")
img7n_1=sw4.read_image("/Users/rshimony/Desktop/WillametteValley/Models/no_refinement_figs/rfile_steph_basin_salem_cart_eugspe_sm/image.cycle=0000.y=140000.s.sw4img")
img8n_1=sw4.read_image("/Users/rshimony/Desktop/WillametteValley/Models/no_refinement_figs/rfile_steph_basin_salem_cart_eugspe_sm/image.cycle=0000.x=100000.s.sw4img")
img9n_1=sw4.read_image("/Users/rshimony/Desktop/WillametteValley/Models/no_refinement_figs/rfile_steph_basin_salem_cart_eugspe_sm/image.cycle=0000.x=150000.s.sw4img")
img10n_1=sw4.read_image("/Users/rshimony/Desktop/WillametteValley/Models/no_refinement_figs/rfile_steph_basin_salem_cart_eugspe_sm/image.cycle=0000.x=190000.s.sw4img")
img11n_1=sw4.read_image("/Users/rshimony/Desktop/WillametteValley/Models/no_refinement_figs/rfile_steph_basin_salem_cart_eugspe_sm/image.cycle=0000.x=275000.s.sw4img")

# %%
fig1,ax1,cb1=img1n_1.plot()
fig1.set_size_inches(12,12)
fig2,ax2,cb2=img2n_1.plot()
fig2.set_size_inches(20,20)
fig3,ax3,cb3=img3n_1.plot()
fig3.set_size_inches(20,20)
fig4,ax4,cb4=img4n_1.plot()
fig4.set_size_inches(20,20)
fig5,ax5,cb5=img5n_1.plot()
fig5.set_size_inches(20,20)
fig6,ax6,cb6=img6n_1.plot()
fig6.set_size_inches(20,20)
fig7,ax7,cb7=img7n_1.plot()
fig7.set_size_inches(20,20)
fig8,ax8,cb8=img8n_1.plot()
fig8.set_size_inches(20,20)
fig9,ax9,cb9=img9n_1.plot()
fig9.set_size_inches(20,20)
fig10,ax10,cb10=img10n_1.plot()
fig10.set_size_inches(20,20)
fig11,ax11,cb11=img11n_1.plot()
fig11.set_size_inches(20,20)
plt.show()

# %%
img1n_hmax=sw4.read_image("/Users/rshimony/Desktop/WillametteValley/Models/rfile_stephenson_salem_topo/image.cycle=2414.z=0.magdudt.sw4img")
fig1,ax1,cb1=img1n_hmax.plot()
fig1.set_size_inches(15,15)

img1n_hmax=sw4.read_image("/Users/rshimony/Desktop/WillametteValley/Models/gp2_singmat/results/image.cycle=2419.z=0.magdudt.sw4img")
fig1,ax1,cb1=img1n_hmax.plot()
fig1.set_size_inches(15,15)

img1n_hmax=sw4.read_image("/Users/rshimony/Desktop/WillametteValley/Models/eug_spe/eug_spe_singmat/image.cycle=2419.z=0.magdudt.sw4img")
fig1,ax1,cb1=img1n_hmax.plot()
fig1.set_size_inches(15,15)

img1n_hmax=sw4.read_image("/Users/rshimony/Desktop/WillametteValley/Models/gp1_deep_singmat/rfile_steph_basin_salem_gp1_sm/image.cycle=2412.z=0.magdudt.sw4img")
fig1,ax1,cb1=img1n_hmax.plot()
fig1.set_size_inches(15,15)

img1n_hmax=sw4.read_image("/Users/rshimony/Desktop/WillametteValley/Models/rfile_steph_notaper_preempt/image.cycle=2412.z=0.magdudt.sw4img")
fig1,ax1,cb1=img1n_hmax.plot()
fig1.set_size_inches(15,15)

# %%
wv1 = obs.read("/Users/rshimony/Desktop/WillametteValley/Models/gp1_deep_singmat/rfile_steph_basin_salem_gp1_sm/ALVY.xv")
wv1.plot()
wv2 = obs.read("/Users/rshimony/Desktop/WillametteValley/Models/gp1_deep_singmat/rfile_steph_basin_salem_gp1_sm/B027.xv")
wv2.plot()
wv3 = obs.read("/Users/rshimony/Desktop/WillametteValley/Models/gp1_deep_singmat/rfile_steph_basin_salem_gp1_sm/LANE.xv")
wv3.plot()
wv4 = obs.read("/Users/rshimony/Desktop/WillametteValley/Models/gp1_deep_singmat/rfile_steph_basin_salem_gp1_sm/B030.xv")
wv4.plot()
wv5 = obs.read("/Users/rshimony/Desktop/WillametteValley/Models/gp1_deep_singmat/rfile_steph_basin_salem_gp1_sm/B032.xv")
wv5.plot()
wv6 = obs.read("/Users/rshimony/Desktop/WillametteValley/Models/gp1_deep_singmat/rfile_steph_basin_salem_gp1_sm/BUCK.xv")
wv6.plot()
wv7 = obs.read("/Users/rshimony/Desktop/WillametteValley/Models/gp1_deep_singmat/rfile_steph_basin_salem_gp1_sm/COBRA.xv")
wv7.plot()
wv8 = obs.read("/Users/rshimony/Desktop/WillametteValley/Models/gp1_deep_singmat/rfile_steph_basin_salem_gp1_sm/NOMA.xv")
wv8.plot()
wv9 = obs.read("/Users/rshimony/Desktop/WillametteValley/Models/gp1_deep_singmat/rfile_steph_basin_salem_gp1_sm/TAUL3.xv")
wv9.plot()

# %%
image_files=sorted(glob('/Users/rshimony/Desktop/WillametteValley/Models/final_sims/rfile_steph_basin_salem_cart_srv_1d//*.cycle=000*.s.sw4img'))
ims_x = image_files[:5]
ims_y = image_files[6:-1]
ims_x
# Out:
# ['/Users/rshimony/Desktop/WillametteValley/Models/final_sims/rfile_steph_basin_salem_cart_srv_1d/image.cycle=0000.x=100000.s.sw4img',
#  '/Users/rshimony/Desktop/WillametteValley/Models/final_sims/rfile_steph_basin_salem_cart_srv_1d/image.cycle=0000.x=150000.s.sw4img',
#  '/Users/rshimony/Desktop/WillametteValley/Models/final_sims/rfile_steph_basin_salem_cart_srv_1d/image.cycle=0000.x=190000.s.sw4img',
#  '/Users/rshimony/Desktop/WillametteValley/Models/final_sims/rfile_steph_basin_salem_cart_srv_1d/image.cycle=0000.x=218000.s.sw4img',
#  '/Users/rshimony/Desktop/WillametteValley/Models/final_sims/rfile_steph_basin_salem_cart_srv_1d/image.cycle=0000.x=240000.s.sw4img']

# %%
'''
COBRA - x=100000 - 0 - C
NOMA - x=190000 - 2 - B
TAUL3 - x=240000 - 4 - A
'''

# filename=image_files[0]
# image=sw4.read_image(filename)
# layer = image.patches[0]
# model=image.patches[0].data
# # fig,ax=plt.subplots(ncols=1,nrows=1,figsize=(18,6))
# fig,ax=plt.subplots(ncols=1,nrows=1,figsize=(10,4))
# extent=([layer.extent[0],layer.extent[1],layer.extent[3],layer.extent[2]])
# ax.tick_params(axis='both', which='major', labelsize=25)
# ax.set_ylabel('Depth (m)',fontsize=27)
# ax.set_xlabel('W-E (m)',fontsize=27)
# ax.text(4000, 1000, 'C', fontsize = 30,color = 'royalblue', 
#          bbox = dict(facecolor = 'white', alpha = 0.8))
# # im=ax1.imshow(model,extent=extent,cmap='terrain',vmax=3000)
# im=ax.imshow(model,extent=extent,cmap='gist_earth',vmin=100,vmax=3000)
# ax.set_ylim(6000,100)
# # ax.set_xlim(50000,280000)
# ax.set_aspect('auto')
# from mpl_toolkits.axes_grid1.inset_locator import inset_axes
# axins1 = inset_axes(ax, width="25.%",height='7%',loc='lower left',bbox_to_anchor=(0.01, 0.2, 1, 1),
#                    bbox_transform=ax.transAxes, borderpad=2)
# cb=fig.colorbar(im, cax=axins1, orientation="horizontal",ticks=(100,1500,3000))
# cb.set_label('Vs [m/sec]',size=23)
# cb.ax.tick_params(labelsize=23) 
# plt.show()
# # fig.savefig('/Users/rshimony/Desktop/WillametteValley/Models/cs_eugspe_steph_sm_cobra.jpg',dpi=300,bbox_inches='tight')

for i in range(len(ims_x)):
    filename=ims_x[i]
    image=sw4.read_image(filename)
    layer = image.patches[2]
    model=image.patches[2].data
    # fig,ax=plt.subplots(ncols=1,nrows=1,figsize=(18,6))
    fig,ax=plt.subplots(ncols=1,nrows=1,figsize=(10,4))
    extent=([layer.extent[0],layer.extent[1],layer.extent[3],layer.extent[2]])
    ax.set_title(ims_x[i].split('.')[-3] ,size=26)
    ax.tick_params(axis='both', which='major', labelsize=25)
    ax.set_ylabel('Depth (m)',fontsize=27)
    ax.set_xlabel('W-E (m)',fontsize=27)
#     ax.text(4000, 1000, 'C', fontsize = 30,color = 'royalblue', 
#              bbox = dict(facecolor = 'white', alpha = 0.8))
    # im=ax1.imshow(model,extent=extent,cmap='terrain',vmax=3000)
    im=ax.imshow(model,extent=extent,cmap='gist_earth',vmin=100,vmax=3000)
    ax.set_ylim(6000,0)
    # ax.set_xlim(50000,280000)
    ax.set_aspect('auto')
    from mpl_toolkits.axes_grid1.inset_locator import inset_axes
    axins1 = inset_axes(ax, width="25.%",height='7%',loc='lower left',bbox_to_anchor=(0.01, 0.2, 1, 1),
                       bbox_transform=ax.transAxes, borderpad=2)
    cb=fig.colorbar(im, cax=axins1, orientation="horizontal",ticks=(100,1500,3000))
    cb.set_label('Vs [m/sec]',size=23)
    cb.ax.tick_params(labelsize=23) 
    plt.show()
#     fig.savefig('/Users/rshimony/Desktop/WillametteValley/Models/rfile_ifile_comp_figs/cs_polyfix_'+ims_x[i].split('.')[-3]+'.jpg',dpi=300,bbox_inches='tight')

# %%
for i in range(len(ims_y)):
    filename=ims_y[i]
    image=sw4.read_image(filename)
    layer = image.patches[0]
    model=image.patches[0].data
    fig,ax=plt.subplots(ncols=1,nrows=1,figsize=(18,6))
    extent=([layer.extent[0],layer.extent[1],layer.extent[3],layer.extent[2]])
    ax.set_title(ims_y[i].split('.')[-3] ,size=26)
    ax.tick_params(axis='both', which='major', labelsize=25)
    ax.set_ylabel('Depth (m)',fontsize=27)
    ax.set_xlabel('S-N (m)',fontsize=27)
    # im=ax1.imshow(model,extent=extent,cmap='terrain',vmax=3000)
    im=ax.imshow(model,extent=extent,cmap='gist_earth',vmin=500,vmax=3000)
    ax.set_ylim(6000,0)
    # ax.set_xlim(100000,300000)
    ax.set_aspect('auto')
    from mpl_toolkits.axes_grid1.inset_locator import inset_axes
    axins1 = inset_axes(ax, width="20.%",height='5%',loc='lower left',bbox_to_anchor=(0.01, 0.15, 1, 1),
                       bbox_transform=ax.transAxes, borderpad=2)
    cb=fig.colorbar(im, cax=axins1, orientation="horizontal",ticks=(800,1800,3000))
    cb.set_label('Vs [m/sec]',size=23)
    cb.ax.tick_params(labelsize=23) 
    plt.show()
#     fig.savefig('/Users/rshimony/Desktop/WillametteValley/Models/rfile_ifile_comp_figs/cs_polyfix_'+ims_y[i].split('.')[-3]+'.jpg',dpi=300,bbox_inches='tight')

# %%
image_files=sorted(glob('/Users/rshimony/Desktop/WillametteValley/Models/rfile_stephenson_salem_topo/*.cycle=000*.s.sw4img'))
image_files
# Out:
# ['/Users/rshimony/Desktop/WillametteValley/Models/rfile_stephenson_salem_topo/image.cycle=0000.x=100000.s.sw4img',
#  '/Users/rshimony/Desktop/WillametteValley/Models/rfile_stephenson_salem_topo/image.cycle=0000.x=150000.s.sw4img',
#  '/Users/rshimony/Desktop/WillametteValley/Models/rfile_stephenson_salem_topo/image.cycle=0000.x=190000.s.sw4img',
#  '/Users/rshimony/Desktop/WillametteValley/Models/rfile_stephenson_salem_topo/image.cycle=0000.x=218000.s.sw4img',
#  '/Users/rshimony/Desktop/WillametteValley/Models/rfile_stephenson_salem_topo/image.cycle=0000.x=240000.s.sw4img',
#  '/Users/rshimony/Desktop/WillametteValley/Models/rfile_stephenson_salem_topo/image.cycle=0000.x=275000.s.sw4img',
#  '/Users/rshimony/Desktop/WillametteValley/Models/rfile_stephenson_salem_topo/image.cycle=0000.y=100000.s.sw4img',
#  '/Users/rshimony/Desktop/WillametteValley/Models/rfile_stephenson_salem_topo/image.cycle=0000.y=110000.s.sw4img',
# ...

# %%
filename=image_files[4]
image=sw4.read_image(filename)
layer = image.patches[0]
model=image.patches[0].data
# fig,ax=plt.subplots(ncols=1,nrows=1,figsize=(18,6))
fig,ax=plt.subplots(ncols=1,nrows=1,figsize=(10,4))
extent=([layer.extent[0],layer.extent[1],layer.extent[3],layer.extent[2]])
ax.tick_params(axis='both', which='major', labelsize=25)
ax.set_ylabel('Depth (m)',fontsize=27)
ax.set_xlabel('W-E (m)',fontsize=27)
ax.text(4000, 1000, 'A', fontsize = 30,color = 'royalblue', 
         bbox = dict(facecolor = 'white', alpha = 0.8))
# im=ax1.imshow(model,extent=extent,cmap='terrain',vmax=3000)
im=ax.imshow(model,extent=extent,cmap='gist_earth')
# ax.set_ylim(6000,100)
# ax.set_xlim(50000,280000)
ax.set_aspect('auto')
from mpl_toolkits.axes_grid1.inset_locator import inset_axes
axins1 = inset_axes(ax, width="25.%",height='7%',loc='lower left',bbox_to_anchor=(0.01, 0.2, 1, 1),
                   bbox_transform=ax.transAxes, borderpad=2)
cb=fig.colorbar(im, cax=axins1, orientation="horizontal")
cb.set_label('Vs [m/sec]',size=23)
cb.ax.tick_params(labelsize=23) 
plt.show()
# fig.savefig('/Users/rshimony/Desktop/WillametteValley/Models/cs_d2e_sm_taul3.jpg',dpi=300,bbox_inches='tight')

# %%
filename="/Users/rshimony/Desktop/WillametteValley/Models/eug_spe/eug_spe_singmat/image.cycle=0000.y=90000.s.sw4img"
image=sw4.read_image(filename)

layers = []
for i in range(len(image.patches)):
    layer=image.patches[i]
    layers.append(layer)
layers.reverse()
    
fig,ax=plt.subplots(ncols=1,nrows=len(layers)-1,figsize=(18,10), sharey='row' , sharex='col')
fig.tight_layout(rect=[0.04, 0.03, 1, 0.985])
for i in range(len(layers)-1):
    model = layers[i].data
    extent=([layers[i].extent[0],layers[i].extent[1],layers[i].extent[3],layers[i].extent[2]])
    ax[i].tick_params(axis='both', which='major', labelsize=18)
#     if i == 1:
#         ax[i].set_ylabel('Z (m)',fontsize=22)
    if i == 1:
        ax[i].set_xlabel('W-E (m)',fontsize=22)
    # im=ax1.imshow(model,extent=extent,cmap='terrain',vmax=3000)
    im=ax[i].imshow(model,extent=extent,cmap='gist_earth',vmax=3000,vmin=800)
    # ax.set_ylim(10000,0)
    # ax.set_xlim(100000,300000)
    ax[i].set_aspect('auto')
#     fig.text(0.5, 0.000, 'N-S (m)', ha='center', fontsize = 20)
    fig.text(0.0, 0.5, 'Z (m)', va='center', rotation='vertical', fontsize = 20)
from mpl_toolkits.axes_grid1.inset_locator import inset_axes
axins1 = inset_axes(ax[i], width="20.%",height='5%',loc='lower left',bbox_to_anchor=(0.01, 0.15, 1, 1),
                   bbox_transform=ax[i].transAxes, borderpad=2)
cb=fig.colorbar(im, cax=axins1, orientation="horizontal",ticks=(1000,2000,3000))
cb.set_label('Vs [m/sec]',size=26)
cb.ax.tick_params(labelsize=24) 
# fig.savefig('/Users/rshimony/Desktop/cs_gp2_1d.jpg',dpi=300,bbox_inches='tight',transparent=True)
plt.show()

# %%
image.patches[0]

# %%
layers = []
for i in range(len(image.patches)):
    layer=image.patches[i]
    layers.append(layer)

layers[2].data.min()
# Out:
# 604.70587
